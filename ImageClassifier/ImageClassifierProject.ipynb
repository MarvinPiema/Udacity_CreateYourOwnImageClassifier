# %% [markdown]
# ## Prepare the workspace

# %% [markdown]
# I use Google Colab to train the model and solve the part 1 of the project 2, Image classifier.

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# !unzip "/content/drive/MyDrive/flowers.zip" -d "/content/drive/MyDrive"
# Out:
# Le flux de sortie a été tronqué et ne contient que les 5000 dernières lignes.
#   inflating: /content/drive/MyDrive/flowers/train/48/image_04683.jpg
#   inflating: /content/drive/MyDrive/flowers/train/48/image_04685.jpg
#   inflating: /content/drive/MyDrive/flowers/train/48/image_04686.jpg
#   inflating: /content/drive/MyDrive/flowers/train/48/image_04689.jpg
#   inflating: /content/drive/MyDrive/flowers/train/48/image_04692.jpg
#   inflating: /content/drive/MyDrive/flowers/train/48/image_04694.jpg
#   inflating: /content/drive/MyDrive/flowers/train/48/image_04695.jpg
#   inflating: /content/drive/MyDrive/flowers/train/49/image_06198.jpg
#   inflating: /content/drive/MyDrive/flowers/train/49/image_06199.jpg
#   inflating: /content/drive/MyDrive/flowers/train/49/image_06200.jpg
#   inflating: /content/drive/MyDrive/flowers/train/49/image_06201.jpg
#   inflating: /content/drive/MyDrive/flowers/train/49/image_06203.jpg
#   inflating: /content/drive/MyDrive/flowers/train/49/image_06204.jpg
#   inflating: /content/drive/MyDrive/flowers/train/49/image_06205.jpg
#   inflating: /content/drive/MyDrive/flowers/train/49/image_06206.jpg
#   inflating: /content/drive/MyDrive/flowers/train/49/image_06207.jpg
#   inflating: /content/drive/MyDrive/flowers/train/49/image_06208.jpg
#   inflating: /content/drive/MyDrive/flowers/train/49/image_06211.jpg
#   inflating: /content/drive/MyDrive/flowers/train/49/image_06212.jpg
#   inflating: /content/drive/MyDrive/flowers/train/49/image_06214.jpg
#   inflating: /content/drive/MyDrive/flowers/train/49/image_06217.jpg
#   inflating: /content/drive/MyDrive/flowers/train/49/image_06218.jpg
#   inflating: /content/drive/MyDrive/flowers/train/49/image_06219.jpg
#   inflating: /content/drive/MyDrive/flowers/train/49/image_06220.jpg
#   inflating: /content/drive/MyDrive/flowers/train/49/image_06221.jpg
#   inflating: /content/drive/MyDrive/flowers/train/49/image_06223.jpg
#   inflating: /content/drive/MyDrive/flowers/train/49/image_06224.jpg
#   inflating: /content/drive/MyDrive/flowers/train/49/image_06225.jpg
#   inflating: /content/drive/MyDrive/flowers/train/49/image_06226.jpg
#   inflating: /content/drive/MyDrive/flowers/train/49/image_06227.jpg
#   inflating: /content/drive/MyDrive/flowers/train/49/image_06229.jpg
#   inflating: /content/drive/MyDrive/flowers/train/49/image_06231.jpg
#   inflating: /content/drive/MyDrive/flowers/train/49/image_06232.jpg
#   inflating: /content/drive/MyDrive/flowers/train/49/image_06233.jpg
#   inflating: /content/drive/MyDrive/flowers/train/49/image_06234.jpg
#   inflating: /content/drive/MyDrive/flowers/train/49/image_06236.jpg
#   inflating: /content/drive/MyDrive/flowers/train/49/image_06237.jpg
#   inflating: /content/drive/MyDrive/flowers/train/49/image_06238.jpg
#   inflating: /content/drive/MyDrive/flowers/train/49/image_06239.jpg
#   inflating: /content/drive/MyDrive/flowers/train/49/image_06241.jpg
#   inflating: /content/drive/MyDrive/flowers/train/49/image_06242.jpg
#   inflating: /content/drive/MyDrive/flowers/train/49/image_06243.jpg
#   inflating: /content/drive/MyDrive/flowers/train/49/image_06244.jpg
#   inflating: /content/drive/MyDrive/flowers/train/49/image_06245.jpg
#   inflating: /content/drive/MyDrive/flowers/train/49/image_06246.jpg
#   inflating: /content/drive/MyDrive/flowers/train/5/image_05147.jpg
#   inflating: /content/drive/MyDrive/flowers/train/5/image_05148.jpg
#   inflating: /content/drive/MyDrive/flowers/train/5/image_05149.jpg
#   inflating: /content/drive/MyDrive/flowers/train/5/image_05150.jpg
#   inflating: /content/drive/MyDrive/flowers/train/5/image_05151.jpg
#   inflating: /content/drive/MyDrive/flowers/train/5/image_05152.jpg
#   inflating: /content/drive/MyDrive/flowers/train/5/image_05153.jpg
#   inflating: /content/drive/MyDrive/flowers/train/5/image_05154.jpg
#   inflating: /content/drive/MyDrive/flowers/train/5/image_05155.jpg
#   inflating: /content/drive/MyDrive/flowers/train/5/image_05156.jpg
#   inflating: /content/drive/MyDrive/flowers/train/5/image_05157.jpg
#   inflating: /content/drive/MyDrive/flowers/train/5/image_05158.jpg
#   inflating: /content/drive/MyDrive/flowers/train/5/image_05160.jpg
#   inflating: /content/drive/MyDrive/flowers/train/5/image_05161.jpg
#   inflating: /content/drive/MyDrive/flowers/train/5/image_05162.jpg
#   inflating: /content/drive/MyDrive/flowers/train/5/image_05163.jpg
#   inflating: /content/drive/MyDrive/flowers/train/5/image_05165.jpg
#   inflating: /content/drive/MyDrive/flowers/train/5/image_05167.jpg
#   inflating: /content/drive/MyDrive/flowers/train/5/image_05170.jpg
#   inflating: /content/drive/MyDrive/flowers/train/5/image_05171.jpg
#   inflating: /content/drive/MyDrive/flowers/train/5/image_05172.jpg
#   inflating: /content/drive/MyDrive/flowers/train/5/image_05173.jpg
#   inflating: /content/drive/MyDrive/flowers/train/5/image_05174.jpg
#   inflating: /content/drive/MyDrive/flowers/train/5/image_05175.jpg
#   inflating: /content/drive/MyDrive/flowers/train/5/image_05176.jpg
#   inflating: /content/drive/MyDrive/flowers/train/5/image_05177.jpg
#   inflating: /content/drive/MyDrive/flowers/train/5/image_05178.jpg
#   inflating: /content/drive/MyDrive/flowers/train/5/image_05179.jpg
#   inflating: /content/drive/MyDrive/flowers/train/5/image_05180.jpg
#   inflating: /content/drive/MyDrive/flowers/train/5/image_05181.jpg
#   inflating: /content/drive/MyDrive/flowers/train/5/image_05182.jpg
#   inflating: /content/drive/MyDrive/flowers/train/5/image_05183.jpg
#   inflating: /content/drive/MyDrive/flowers/train/5/image_05184.jpg
#   inflating: /content/drive/MyDrive/flowers/train/5/image_05185.jpg
#   inflating: /content/drive/MyDrive/flowers/train/5/image_05187.jpg
#   inflating: /content/drive/MyDrive/flowers/train/5/image_05189.jpg
#   inflating: /content/drive/MyDrive/flowers/train/5/image_05190.jpg
#   inflating: /content/drive/MyDrive/flowers/train/5/image_05191.jpg
#   inflating: /content/drive/MyDrive/flowers/train/5/image_05193.jpg
#   inflating: /content/drive/MyDrive/flowers/train/5/image_05194.jpg
#   inflating: /content/drive/MyDrive/flowers/train/5/image_05195.jpg
#   inflating: /content/drive/MyDrive/flowers/train/5/image_05197.jpg
#   inflating: /content/drive/MyDrive/flowers/train/5/image_05198.jpg
#   inflating: /content/drive/MyDrive/flowers/train/5/image_05200.jpg
#   inflating: /content/drive/MyDrive/flowers/train/5/image_05201.jpg
#   inflating: /content/drive/MyDrive/flowers/train/5/image_05202.jpg
#   inflating: /content/drive/MyDrive/flowers/train/5/image_05203.jpg
#   inflating: /content/drive/MyDrive/flowers/train/5/image_05204.jpg
#   inflating: /content/drive/MyDrive/flowers/train/5/image_05205.jpg
#   inflating: /content/drive/MyDrive/flowers/train/5/image_05206.jpg
#   inflating: /content/drive/MyDrive/flowers/train/5/image_05207.jpg
#   inflating: /content/drive/MyDrive/flowers/train/5/image_05208.jpg
#   inflating: /content/drive/MyDrive/flowers/train/5/image_05210.jpg
#   inflating: /content/drive/MyDrive/flowers/train/5/image_05211.jpg
#   inflating: /content/drive/MyDrive/flowers/train/50/image_06298.jpg
#   inflating: /content/drive/MyDrive/flowers/train/50/image_06299.jpg
#   inflating: /content/drive/MyDrive/flowers/train/50/image_06300.jpg
#   inflating: /content/drive/MyDrive/flowers/train/50/image_06301.jpg
#   inflating: /content/drive/MyDrive/flowers/train/50/image_06302.jpg
#   inflating: /content/drive/MyDrive/flowers/train/50/image_06303.jpg
#   inflating: /content/drive/MyDrive/flowers/train/50/image_06304.jpg
#   inflating: /content/drive/MyDrive/flowers/train/50/image_06306.jpg
#   inflating: /content/drive/MyDrive/flowers/train/50/image_06307.jpg
#   inflating: /content/drive/MyDrive/flowers/train/50/image_06308.jpg
#   inflating: /content/drive/MyDrive/flowers/train/50/image_06309.jpg
#   inflating: /content/drive/MyDrive/flowers/train/50/image_06310.jpg
#   inflating: /content/drive/MyDrive/flowers/train/50/image_06312.jpg
#   inflating: /content/drive/MyDrive/flowers/train/50/image_06313.jpg
#   inflating: /content/drive/MyDrive/flowers/train/50/image_06314.jpg
#   inflating: /content/drive/MyDrive/flowers/train/50/image_06315.jpg
#   inflating: /content/drive/MyDrive/flowers/train/50/image_06316.jpg
#   inflating: /content/drive/MyDrive/flowers/train/50/image_06317.jpg
#   inflating: /content/drive/MyDrive/flowers/train/50/image_06322.jpg
#   inflating: /content/drive/MyDrive/flowers/train/50/image_06323.jpg
#   inflating: /content/drive/MyDrive/flowers/train/50/image_06325.jpg
#   inflating: /content/drive/MyDrive/flowers/train/50/image_06326.jpg
#   inflating: /content/drive/MyDrive/flowers/train/50/image_06327.jpg
#   inflating: /content/drive/MyDrive/flowers/train/50/image_06328.jpg
#   inflating: /content/drive/MyDrive/flowers/train/50/image_06329.jpg
#   inflating: /content/drive/MyDrive/flowers/train/50/image_06330.jpg
#   inflating: /content/drive/MyDrive/flowers/train/50/image_06332.jpg
#   inflating: /content/drive/MyDrive/flowers/train/50/image_06333.jpg
#   inflating: /content/drive/MyDrive/flowers/train/50/image_06334.jpg
#   inflating: /content/drive/MyDrive/flowers/train/50/image_06335.jpg
#   inflating: /content/drive/MyDrive/flowers/train/50/image_06336.jpg
#   inflating: /content/drive/MyDrive/flowers/train/50/image_06337.jpg
#   inflating: /content/drive/MyDrive/flowers/train/50/image_06338.jpg
#   inflating: /content/drive/MyDrive/flowers/train/50/image_06339.jpg
#   inflating: /content/drive/MyDrive/flowers/train/50/image_06340.jpg
#   inflating: /content/drive/MyDrive/flowers/train/50/image_06341.jpg
#   inflating: /content/drive/MyDrive/flowers/train/50/image_06342.jpg
#   inflating: /content/drive/MyDrive/flowers/train/50/image_06343.jpg
#   inflating: /content/drive/MyDrive/flowers/train/50/image_06344.jpg
#   inflating: /content/drive/MyDrive/flowers/train/50/image_06345.jpg
#   inflating: /content/drive/MyDrive/flowers/train/50/image_06529.jpg
#   inflating: /content/drive/MyDrive/flowers/train/50/image_06530.jpg
#   inflating: /content/drive/MyDrive/flowers/train/50/image_06531.jpg
#   inflating: /content/drive/MyDrive/flowers/train/50/image_06532.jpg
#   inflating: /content/drive/MyDrive/flowers/train/50/image_06533.jpg
#   inflating: /content/drive/MyDrive/flowers/train/50/image_06535.jpg
#   inflating: /content/drive/MyDrive/flowers/train/50/image_06536.jpg
#   inflating: /content/drive/MyDrive/flowers/train/50/image_06537.jpg
#   inflating: /content/drive/MyDrive/flowers/train/50/image_06538.jpg
#   inflating: /content/drive/MyDrive/flowers/train/50/image_06539.jpg
#   inflating: /content/drive/MyDrive/flowers/train/50/image_06540.jpg
#   inflating: /content/drive/MyDrive/flowers/train/50/image_06542.jpg
#   inflating: /content/drive/MyDrive/flowers/train/50/image_06543.jpg
#   inflating: /content/drive/MyDrive/flowers/train/50/image_06545.jpg
#   inflating: /content/drive/MyDrive/flowers/train/50/image_06548.jpg
#   inflating: /content/drive/MyDrive/flowers/train/50/image_06549.jpg
#   inflating: /content/drive/MyDrive/flowers/train/50/image_06551.jpg
#   inflating: /content/drive/MyDrive/flowers/train/50/image_06553.jpg
#   inflating: /content/drive/MyDrive/flowers/train/50/image_06554.jpg
#   inflating: /content/drive/MyDrive/flowers/train/50/image_06555.jpg
#   inflating: /content/drive/MyDrive/flowers/train/50/image_06556.jpg
#   inflating: /content/drive/MyDrive/flowers/train/50/image_06557.jpg
#   inflating: /content/drive/MyDrive/flowers/train/50/image_06559.jpg
#   inflating: /content/drive/MyDrive/flowers/train/50/image_06560.jpg
#   inflating: /content/drive/MyDrive/flowers/train/50/image_06561.jpg
#   inflating: /content/drive/MyDrive/flowers/train/50/image_06563.jpg
#   inflating: /content/drive/MyDrive/flowers/train/50/image_06564.jpg
#   inflating: /content/drive/MyDrive/flowers/train/50/image_06565.jpg
#   inflating: /content/drive/MyDrive/flowers/train/50/image_06566.jpg
#   inflating: /content/drive/MyDrive/flowers/train/50/image_06567.jpg
#   inflating: /content/drive/MyDrive/flowers/train/50/image_06568.jpg
#   inflating: /content/drive/MyDrive/flowers/train/50/image_06569.jpg
#   inflating: /content/drive/MyDrive/flowers/train/50/image_06570.jpg
#   inflating: /content/drive/MyDrive/flowers/train/51/image_01317.jpg
#   inflating: /content/drive/MyDrive/flowers/train/51/image_01318.jpg
#   inflating: /content/drive/MyDrive/flowers/train/51/image_01319.jpg
#   inflating: /content/drive/MyDrive/flowers/train/51/image_01320.jpg
#   inflating: /content/drive/MyDrive/flowers/train/51/image_01321.jpg
#   inflating: /content/drive/MyDrive/flowers/train/51/image_01323.jpg
#   inflating: /content/drive/MyDrive/flowers/train/51/image_01324.jpg
#   inflating: /content/drive/MyDrive/flowers/train/51/image_01325.jpg
#   inflating: /content/drive/MyDrive/flowers/train/51/image_01327.jpg
#   inflating: /content/drive/MyDrive/flowers/train/51/image_01329.jpg
#   inflating: /content/drive/MyDrive/flowers/train/51/image_01330.jpg
#   inflating: /content/drive/MyDrive/flowers/train/51/image_01331.jpg
#   inflating: /content/drive/MyDrive/flowers/train/51/image_01332.jpg
#   inflating: /content/drive/MyDrive/flowers/train/51/image_01333.jpg
#   inflating: /content/drive/MyDrive/flowers/train/51/image_01334.jpg
#   inflating: /content/drive/MyDrive/flowers/train/51/image_01336.jpg
#   inflating: /content/drive/MyDrive/flowers/train/51/image_01337.jpg
#   inflating: /content/drive/MyDrive/flowers/train/51/image_01338.jpg
#   inflating: /content/drive/MyDrive/flowers/train/51/image_01339.jpg
#   inflating: /content/drive/MyDrive/flowers/train/51/image_01341.jpg
#   inflating: /content/drive/MyDrive/flowers/train/51/image_01342.jpg
#   inflating: /content/drive/MyDrive/flowers/train/51/image_01343.jpg
#   inflating: /content/drive/MyDrive/flowers/train/51/image_01344.jpg
#   inflating: /content/drive/MyDrive/flowers/train/51/image_01345.jpg
#   inflating: /content/drive/MyDrive/flowers/train/51/image_01347.jpg
#   inflating: /content/drive/MyDrive/flowers/train/51/image_01348.jpg
#   inflating: /content/drive/MyDrive/flowers/train/51/image_01349.jpg
#   inflating: /content/drive/MyDrive/flowers/train/51/image_01350.jpg
#   inflating: /content/drive/MyDrive/flowers/train/51/image_01351.jpg
#   inflating: /content/drive/MyDrive/flowers/train/51/image_01353.jpg
#   inflating: /content/drive/MyDrive/flowers/train/51/image_01355.jpg
#   inflating: /content/drive/MyDrive/flowers/train/51/image_01356.jpg
#   inflating: /content/drive/MyDrive/flowers/train/51/image_01357.jpg
#   inflating: /content/drive/MyDrive/flowers/train/51/image_01358.jpg
#   inflating: /content/drive/MyDrive/flowers/train/51/image_01359.jpg
#   inflating: /content/drive/MyDrive/flowers/train/51/image_01360.jpg
#   inflating: /content/drive/MyDrive/flowers/train/51/image_01361.jpg
#   inflating: /content/drive/MyDrive/flowers/train/51/image_01364.jpg
#   inflating: /content/drive/MyDrive/flowers/train/51/image_01365.jpg
#   inflating: /content/drive/MyDrive/flowers/train/51/image_01366.jpg
#   inflating: /content/drive/MyDrive/flowers/train/51/image_01367.jpg
#   inflating: /content/drive/MyDrive/flowers/train/51/image_01368.jpg
#   inflating: /content/drive/MyDrive/flowers/train/51/image_01369.jpg
#   inflating: /content/drive/MyDrive/flowers/train/51/image_01371.jpg
#   inflating: /content/drive/MyDrive/flowers/train/51/image_01372.jpg
#   inflating: /content/drive/MyDrive/flowers/train/51/image_01373.jpg
#   inflating: /content/drive/MyDrive/flowers/train/51/image_01374.jpg
#   inflating: /content/drive/MyDrive/flowers/train/51/image_01375.jpg
#   inflating: /content/drive/MyDrive/flowers/train/51/image_01376.jpg
#   inflating: /content/drive/MyDrive/flowers/train/51/image_01377.jpg
#   inflating: /content/drive/MyDrive/flowers/train/51/image_01378.jpg
#   inflating: /content/drive/MyDrive/flowers/train/51/image_01379.jpg
#   inflating: /content/drive/MyDrive/flowers/train/51/image_01380.jpg
#   inflating: /content/drive/MyDrive/flowers/train/51/image_01381.jpg
#   inflating: /content/drive/MyDrive/flowers/train/51/image_01382.jpg
#   inflating: /content/drive/MyDrive/flowers/train/51/image_01383.jpg
#   inflating: /content/drive/MyDrive/flowers/train/51/image_01384.jpg
#   inflating: /content/drive/MyDrive/flowers/train/51/image_01385.jpg
#   inflating: /content/drive/MyDrive/flowers/train/51/image_01386.jpg
#   inflating: /content/drive/MyDrive/flowers/train/51/image_01387.jpg
#   inflating: /content/drive/MyDrive/flowers/train/51/image_01390.jpg
#   inflating: /content/drive/MyDrive/flowers/train/51/image_01392.jpg
#   inflating: /content/drive/MyDrive/flowers/train/51/image_01393.jpg
#   inflating: /content/drive/MyDrive/flowers/train/51/image_01394.jpg
#   inflating: /content/drive/MyDrive/flowers/train/51/image_01395.jpg
#   inflating: /content/drive/MyDrive/flowers/train/51/image_01396.jpg
#   inflating: /content/drive/MyDrive/flowers/train/51/image_01397.jpg
#   inflating: /content/drive/MyDrive/flowers/train/51/image_01398.jpg
#   inflating: /content/drive/MyDrive/flowers/train/51/image_01399.jpg
#   inflating: /content/drive/MyDrive/flowers/train/51/image_01400.jpg
#   inflating: /content/drive/MyDrive/flowers/train/51/image_01401.jpg
#   inflating: /content/drive/MyDrive/flowers/train/51/image_01402.jpg
#   inflating: /content/drive/MyDrive/flowers/train/51/image_01403.jpg
#   inflating: /content/drive/MyDrive/flowers/train/51/image_01404.jpg
#   inflating: /content/drive/MyDrive/flowers/train/51/image_01405.jpg
#   inflating: /content/drive/MyDrive/flowers/train/51/image_01408.jpg
#   inflating: /content/drive/MyDrive/flowers/train/51/image_01409.jpg
#   inflating: /content/drive/MyDrive/flowers/train/51/image_01410.jpg
#   inflating: /content/drive/MyDrive/flowers/train/51/image_01411.jpg
#   inflating: /content/drive/MyDrive/flowers/train/51/image_01412.jpg
#   inflating: /content/drive/MyDrive/flowers/train/51/image_01413.jpg
#   inflating: /content/drive/MyDrive/flowers/train/51/image_01415.jpg
#   inflating: /content/drive/MyDrive/flowers/train/51/image_01416.jpg
#   inflating: /content/drive/MyDrive/flowers/train/51/image_01417.jpg
#   inflating: /content/drive/MyDrive/flowers/train/51/image_01418.jpg
#   inflating: /content/drive/MyDrive/flowers/train/51/image_01420.jpg
#   inflating: /content/drive/MyDrive/flowers/train/51/image_01421.jpg
#   inflating: /content/drive/MyDrive/flowers/train/51/image_01422.jpg
#   inflating: /content/drive/MyDrive/flowers/train/51/image_01423.jpg
#   inflating: /content/drive/MyDrive/flowers/train/51/image_01424.jpg
#   inflating: /content/drive/MyDrive/flowers/train/51/image_01426.jpg
#   inflating: /content/drive/MyDrive/flowers/train/51/image_01427.jpg
#   inflating: /content/drive/MyDrive/flowers/train/51/image_01428.jpg
#   inflating: /content/drive/MyDrive/flowers/train/51/image_01429.jpg
#   inflating: /content/drive/MyDrive/flowers/train/51/image_01430.jpg
#   inflating: /content/drive/MyDrive/flowers/train/51/image_01431.jpg
#   inflating: /content/drive/MyDrive/flowers/train/51/image_01432.jpg
#   inflating: /content/drive/MyDrive/flowers/train/51/image_01433.jpg
#   inflating: /content/drive/MyDrive/flowers/train/51/image_01434.jpg
#   inflating: /content/drive/MyDrive/flowers/train/51/image_01435.jpg
#   inflating: /content/drive/MyDrive/flowers/train/51/image_01436.jpg
#   inflating: /content/drive/MyDrive/flowers/train/51/image_01437.jpg
#   inflating: /content/drive/MyDrive/flowers/train/51/image_01438.jpg
#   inflating: /content/drive/MyDrive/flowers/train/51/image_01440.jpg
#   inflating: /content/drive/MyDrive/flowers/train/51/image_01441.jpg
#   inflating: /content/drive/MyDrive/flowers/train/51/image_01442.jpg
#   inflating: /content/drive/MyDrive/flowers/train/51/image_01443.jpg
#   inflating: /content/drive/MyDrive/flowers/train/51/image_01444.jpg
#   inflating: /content/drive/MyDrive/flowers/train/51/image_01445.jpg
#   inflating: /content/drive/MyDrive/flowers/train/51/image_01446.jpg
#   inflating: /content/drive/MyDrive/flowers/train/51/image_01447.jpg
#   inflating: /content/drive/MyDrive/flowers/train/51/image_01448.jpg
#   inflating: /content/drive/MyDrive/flowers/train/51/image_01449.jpg
#   inflating: /content/drive/MyDrive/flowers/train/51/image_01450.jpg
#   inflating: /content/drive/MyDrive/flowers/train/51/image_01451.jpg
#   inflating: /content/drive/MyDrive/flowers/train/51/image_01452.jpg
#   inflating: /content/drive/MyDrive/flowers/train/51/image_01453.jpg
#   inflating: /content/drive/MyDrive/flowers/train/51/image_01454.jpg
#   inflating: /content/drive/MyDrive/flowers/train/51/image_01455.jpg
#   inflating: /content/drive/MyDrive/flowers/train/51/image_01456.jpg
#   inflating: /content/drive/MyDrive/flowers/train/51/image_01458.jpg
#   inflating: /content/drive/MyDrive/flowers/train/51/image_01460.jpg
#   inflating: /content/drive/MyDrive/flowers/train/51/image_01461.jpg
#   inflating: /content/drive/MyDrive/flowers/train/51/image_01462.jpg
#   inflating: /content/drive/MyDrive/flowers/train/51/image_01463.jpg
#   inflating: /content/drive/MyDrive/flowers/train/51/image_01464.jpg
#   inflating: /content/drive/MyDrive/flowers/train/51/image_01465.jpg
#   inflating: /content/drive/MyDrive/flowers/train/51/image_01466.jpg
#   inflating: /content/drive/MyDrive/flowers/train/51/image_01467.jpg
#   inflating: /content/drive/MyDrive/flowers/train/51/image_01470.jpg
#   inflating: /content/drive/MyDrive/flowers/train/51/image_01471.jpg
#   inflating: /content/drive/MyDrive/flowers/train/51/image_01472.jpg
#   inflating: /content/drive/MyDrive/flowers/train/51/image_01475.jpg
#   inflating: /content/drive/MyDrive/flowers/train/51/image_01476.jpg
#   inflating: /content/drive/MyDrive/flowers/train/51/image_01477.jpg
#   inflating: /content/drive/MyDrive/flowers/train/51/image_01478.jpg
#   inflating: /content/drive/MyDrive/flowers/train/51/image_01479.jpg
#   inflating: /content/drive/MyDrive/flowers/train/51/image_01480.jpg
#   inflating: /content/drive/MyDrive/flowers/train/51/image_01481.jpg
#   inflating: /content/drive/MyDrive/flowers/train/51/image_01482.jpg
#   inflating: /content/drive/MyDrive/flowers/train/51/image_01483.jpg
#   inflating: /content/drive/MyDrive/flowers/train/51/image_01484.jpg
#   inflating: /content/drive/MyDrive/flowers/train/51/image_01485.jpg
#   inflating: /content/drive/MyDrive/flowers/train/51/image_01486.jpg
#   inflating: /content/drive/MyDrive/flowers/train/51/image_01487.jpg
#   inflating: /content/drive/MyDrive/flowers/train/51/image_01488.jpg
#   inflating: /content/drive/MyDrive/flowers/train/51/image_01489.jpg
#   inflating: /content/drive/MyDrive/flowers/train/51/image_01490.jpg
#   inflating: /content/drive/MyDrive/flowers/train/51/image_03913.jpg
#   inflating: /content/drive/MyDrive/flowers/train/51/image_03914.jpg
#   inflating: /content/drive/MyDrive/flowers/train/51/image_03915.jpg
#   inflating: /content/drive/MyDrive/flowers/train/51/image_03918.jpg
#   inflating: /content/drive/MyDrive/flowers/train/51/image_03919.jpg
#   inflating: /content/drive/MyDrive/flowers/train/51/image_03920.jpg
#   inflating: /content/drive/MyDrive/flowers/train/51/image_03921.jpg
#   inflating: /content/drive/MyDrive/flowers/train/51/image_03922.jpg
#   inflating: /content/drive/MyDrive/flowers/train/51/image_03923.jpg
#   inflating: /content/drive/MyDrive/flowers/train/51/image_03924.jpg
#   inflating: /content/drive/MyDrive/flowers/train/51/image_03925.jpg
#   inflating: /content/drive/MyDrive/flowers/train/51/image_03928.jpg
#   inflating: /content/drive/MyDrive/flowers/train/51/image_03929.jpg
#   inflating: /content/drive/MyDrive/flowers/train/51/image_03930.jpg
#   inflating: /content/drive/MyDrive/flowers/train/51/image_03931.jpg
#   inflating: /content/drive/MyDrive/flowers/train/51/image_03932.jpg
#   inflating: /content/drive/MyDrive/flowers/train/51/image_03934.jpg
#   inflating: /content/drive/MyDrive/flowers/train/51/image_03935.jpg
#   inflating: /content/drive/MyDrive/flowers/train/51/image_03936.jpg
#   inflating: /content/drive/MyDrive/flowers/train/51/image_03940.jpg
#   inflating: /content/drive/MyDrive/flowers/train/51/image_03941.jpg
#   inflating: /content/drive/MyDrive/flowers/train/51/image_03942.jpg
#   inflating: /content/drive/MyDrive/flowers/train/51/image_03944.jpg
#   inflating: /content/drive/MyDrive/flowers/train/51/image_03945.jpg
#   inflating: /content/drive/MyDrive/flowers/train/51/image_03947.jpg
#   inflating: /content/drive/MyDrive/flowers/train/51/image_03948.jpg
#   inflating: /content/drive/MyDrive/flowers/train/51/image_03949.jpg
#   inflating: /content/drive/MyDrive/flowers/train/51/image_03950.jpg
#   inflating: /content/drive/MyDrive/flowers/train/51/image_03952.jpg
#   inflating: /content/drive/MyDrive/flowers/train/51/image_03953.jpg
#   inflating: /content/drive/MyDrive/flowers/train/51/image_03955.jpg
#   inflating: /content/drive/MyDrive/flowers/train/51/image_03956.jpg
#   inflating: /content/drive/MyDrive/flowers/train/51/image_03957.jpg
#   inflating: /content/drive/MyDrive/flowers/train/51/image_03958.jpg
#   inflating: /content/drive/MyDrive/flowers/train/51/image_03959.jpg
#   inflating: /content/drive/MyDrive/flowers/train/51/image_03962.jpg
#   inflating: /content/drive/MyDrive/flowers/train/51/image_03963.jpg
#   inflating: /content/drive/MyDrive/flowers/train/51/image_03964.jpg
#   inflating: /content/drive/MyDrive/flowers/train/51/image_03965.jpg
#   inflating: /content/drive/MyDrive/flowers/train/51/image_03966.jpg
#   inflating: /content/drive/MyDrive/flowers/train/51/image_03967.jpg
#   inflating: /content/drive/MyDrive/flowers/train/51/image_03969.jpg
#   inflating: /content/drive/MyDrive/flowers/train/51/image_03970.jpg
#   inflating: /content/drive/MyDrive/flowers/train/51/image_03971.jpg
#   inflating: /content/drive/MyDrive/flowers/train/51/image_03972.jpg
#   inflating: /content/drive/MyDrive/flowers/train/51/image_03976.jpg
#   inflating: /content/drive/MyDrive/flowers/train/51/image_03977.jpg
#   inflating: /content/drive/MyDrive/flowers/train/51/image_03978.jpg
#   inflating: /content/drive/MyDrive/flowers/train/51/image_03979.jpg
#   inflating: /content/drive/MyDrive/flowers/train/51/image_03981.jpg
#   inflating: /content/drive/MyDrive/flowers/train/51/image_03982.jpg
#   inflating: /content/drive/MyDrive/flowers/train/51/image_03983.jpg
#   inflating: /content/drive/MyDrive/flowers/train/51/image_03987.jpg
#   inflating: /content/drive/MyDrive/flowers/train/51/image_03988.jpg
#   inflating: /content/drive/MyDrive/flowers/train/51/image_03990.jpg
#   inflating: /content/drive/MyDrive/flowers/train/51/image_03991.jpg
#   inflating: /content/drive/MyDrive/flowers/train/51/image_03992.jpg
#   inflating: /content/drive/MyDrive/flowers/train/51/image_03993.jpg
#   inflating: /content/drive/MyDrive/flowers/train/52/image_04159.jpg
#   inflating: /content/drive/MyDrive/flowers/train/52/image_04161.jpg
#   inflating: /content/drive/MyDrive/flowers/train/52/image_04162.jpg
#   inflating: /content/drive/MyDrive/flowers/train/52/image_04164.jpg
#   inflating: /content/drive/MyDrive/flowers/train/52/image_04165.jpg
#   inflating: /content/drive/MyDrive/flowers/train/52/image_04166.jpg
#   inflating: /content/drive/MyDrive/flowers/train/52/image_04170.jpg
#   inflating: /content/drive/MyDrive/flowers/train/52/image_04171.jpg
#   inflating: /content/drive/MyDrive/flowers/train/52/image_04174.jpg
#   inflating: /content/drive/MyDrive/flowers/train/52/image_04175.jpg
#   inflating: /content/drive/MyDrive/flowers/train/52/image_04176.jpg
#   inflating: /content/drive/MyDrive/flowers/train/52/image_04177.jpg
#   inflating: /content/drive/MyDrive/flowers/train/52/image_04178.jpg
#   inflating: /content/drive/MyDrive/flowers/train/52/image_04179.jpg
#   inflating: /content/drive/MyDrive/flowers/train/52/image_04180.jpg
#   inflating: /content/drive/MyDrive/flowers/train/52/image_04183.jpg
#   inflating: /content/drive/MyDrive/flowers/train/52/image_04184.jpg
#   inflating: /content/drive/MyDrive/flowers/train/52/image_04185.jpg
#   inflating: /content/drive/MyDrive/flowers/train/52/image_04186.jpg
#   inflating: /content/drive/MyDrive/flowers/train/52/image_04187.jpg
#   inflating: /content/drive/MyDrive/flowers/train/52/image_04188.jpg
#   inflating: /content/drive/MyDrive/flowers/train/52/image_04189.jpg
#   inflating: /content/drive/MyDrive/flowers/train/52/image_04190.jpg
#   inflating: /content/drive/MyDrive/flowers/train/52/image_04192.jpg
#   inflating: /content/drive/MyDrive/flowers/train/52/image_04193.jpg
#   inflating: /content/drive/MyDrive/flowers/train/52/image_04194.jpg
#   inflating: /content/drive/MyDrive/flowers/train/52/image_04195.jpg
#   inflating: /content/drive/MyDrive/flowers/train/52/image_04196.jpg
#   inflating: /content/drive/MyDrive/flowers/train/52/image_04197.jpg
#   inflating: /content/drive/MyDrive/flowers/train/52/image_04198.jpg
#   inflating: /content/drive/MyDrive/flowers/train/52/image_04199.jpg
#   inflating: /content/drive/MyDrive/flowers/train/52/image_04201.jpg
#   inflating: /content/drive/MyDrive/flowers/train/52/image_04202.jpg
#   inflating: /content/drive/MyDrive/flowers/train/52/image_04203.jpg
#   inflating: /content/drive/MyDrive/flowers/train/52/image_04204.jpg
#   inflating: /content/drive/MyDrive/flowers/train/52/image_04205.jpg
#   inflating: /content/drive/MyDrive/flowers/train/52/image_04206.jpg
#   inflating: /content/drive/MyDrive/flowers/train/52/image_04208.jpg
#   inflating: /content/drive/MyDrive/flowers/train/52/image_04209.jpg
#   inflating: /content/drive/MyDrive/flowers/train/52/image_04210.jpg
#   inflating: /content/drive/MyDrive/flowers/train/52/image_04211.jpg
#   inflating: /content/drive/MyDrive/flowers/train/52/image_04212.jpg
#   inflating: /content/drive/MyDrive/flowers/train/52/image_04213.jpg
#   inflating: /content/drive/MyDrive/flowers/train/52/image_04214.jpg
#   inflating: /content/drive/MyDrive/flowers/train/52/image_04216.jpg
#   inflating: /content/drive/MyDrive/flowers/train/52/image_04217.jpg
#   inflating: /content/drive/MyDrive/flowers/train/52/image_04218.jpg
#   inflating: /content/drive/MyDrive/flowers/train/52/image_04219.jpg
#   inflating: /content/drive/MyDrive/flowers/train/52/image_04220.jpg
#   inflating: /content/drive/MyDrive/flowers/train/52/image_04222.jpg
#   inflating: /content/drive/MyDrive/flowers/train/52/image_04223.jpg
#   inflating: /content/drive/MyDrive/flowers/train/52/image_04224.jpg
#   inflating: /content/drive/MyDrive/flowers/train/52/image_04226.jpg
#   inflating: /content/drive/MyDrive/flowers/train/52/image_04227.jpg
#   inflating: /content/drive/MyDrive/flowers/train/52/image_04228.jpg
#   inflating: /content/drive/MyDrive/flowers/train/52/image_04229.jpg
#   inflating: /content/drive/MyDrive/flowers/train/52/image_04230.jpg
#   inflating: /content/drive/MyDrive/flowers/train/52/image_04231.jpg
#   inflating: /content/drive/MyDrive/flowers/train/52/image_04232.jpg
#   inflating: /content/drive/MyDrive/flowers/train/52/image_04233.jpg
#   inflating: /content/drive/MyDrive/flowers/train/52/image_04234.jpg
#   inflating: /content/drive/MyDrive/flowers/train/52/image_04236.jpg
#   inflating: /content/drive/MyDrive/flowers/train/52/image_04237.jpg
#   inflating: /content/drive/MyDrive/flowers/train/52/image_04239.jpg
#   inflating: /content/drive/MyDrive/flowers/train/52/image_04241.jpg
#   inflating: /content/drive/MyDrive/flowers/train/52/image_04242.jpg
#   inflating: /content/drive/MyDrive/flowers/train/52/image_04243.jpg
#   inflating: /content/drive/MyDrive/flowers/train/53/image_03641.jpg
#   inflating: /content/drive/MyDrive/flowers/train/53/image_03642.jpg
#   inflating: /content/drive/MyDrive/flowers/train/53/image_03643.jpg
#   inflating: /content/drive/MyDrive/flowers/train/53/image_03644.jpg
#   inflating: /content/drive/MyDrive/flowers/train/53/image_03646.jpg
#   inflating: /content/drive/MyDrive/flowers/train/53/image_03647.jpg
#   inflating: /content/drive/MyDrive/flowers/train/53/image_03648.jpg
#   inflating: /content/drive/MyDrive/flowers/train/53/image_03650.jpg
#   inflating: /content/drive/MyDrive/flowers/train/53/image_03651.jpg
#   inflating: /content/drive/MyDrive/flowers/train/53/image_03657.jpg
#   inflating: /content/drive/MyDrive/flowers/train/53/image_03658.jpg
#   inflating: /content/drive/MyDrive/flowers/train/53/image_03659.jpg
#   inflating: /content/drive/MyDrive/flowers/train/53/image_03660.jpg
#   inflating: /content/drive/MyDrive/flowers/train/53/image_03661.jpg
#   inflating: /content/drive/MyDrive/flowers/train/53/image_03663.jpg
#   inflating: /content/drive/MyDrive/flowers/train/53/image_03664.jpg
#   inflating: /content/drive/MyDrive/flowers/train/53/image_03665.jpg
#   inflating: /content/drive/MyDrive/flowers/train/53/image_03666.jpg
#   inflating: /content/drive/MyDrive/flowers/train/53/image_03671.jpg
#   inflating: /content/drive/MyDrive/flowers/train/53/image_03673.jpg
#   inflating: /content/drive/MyDrive/flowers/train/53/image_03674.jpg
#   inflating: /content/drive/MyDrive/flowers/train/53/image_03675.jpg
#   inflating: /content/drive/MyDrive/flowers/train/53/image_03676.jpg
#   inflating: /content/drive/MyDrive/flowers/train/53/image_03678.jpg
#   inflating: /content/drive/MyDrive/flowers/train/53/image_03679.jpg
#   inflating: /content/drive/MyDrive/flowers/train/53/image_03680.jpg
#   inflating: /content/drive/MyDrive/flowers/train/53/image_03681.jpg
#   inflating: /content/drive/MyDrive/flowers/train/53/image_03682.jpg
#   inflating: /content/drive/MyDrive/flowers/train/53/image_03683.jpg
#   inflating: /content/drive/MyDrive/flowers/train/53/image_03684.jpg
#   inflating: /content/drive/MyDrive/flowers/train/53/image_03685.jpg
#   inflating: /content/drive/MyDrive/flowers/train/53/image_03686.jpg
#   inflating: /content/drive/MyDrive/flowers/train/53/image_03687.jpg
#   inflating: /content/drive/MyDrive/flowers/train/53/image_03688.jpg
#   inflating: /content/drive/MyDrive/flowers/train/53/image_03690.jpg
#   inflating: /content/drive/MyDrive/flowers/train/53/image_03691.jpg
#   inflating: /content/drive/MyDrive/flowers/train/53/image_03692.jpg
#   inflating: /content/drive/MyDrive/flowers/train/53/image_03694.jpg
#   inflating: /content/drive/MyDrive/flowers/train/53/image_03695.jpg
#   inflating: /content/drive/MyDrive/flowers/train/53/image_03696.jpg
#   inflating: /content/drive/MyDrive/flowers/train/53/image_03697.jpg
#   inflating: /content/drive/MyDrive/flowers/train/53/image_03698.jpg
#   inflating: /content/drive/MyDrive/flowers/train/53/image_03699.jpg
#   inflating: /content/drive/MyDrive/flowers/train/53/image_03700.jpg
#   inflating: /content/drive/MyDrive/flowers/train/53/image_03701.jpg
#   inflating: /content/drive/MyDrive/flowers/train/53/image_03703.jpg
#   inflating: /content/drive/MyDrive/flowers/train/53/image_03704.jpg
#   inflating: /content/drive/MyDrive/flowers/train/53/image_03705.jpg
#   inflating: /content/drive/MyDrive/flowers/train/53/image_03706.jpg
#   inflating: /content/drive/MyDrive/flowers/train/53/image_03707.jpg
#   inflating: /content/drive/MyDrive/flowers/train/53/image_03708.jpg
#   inflating: /content/drive/MyDrive/flowers/train/53/image_03709.jpg
#   inflating: /content/drive/MyDrive/flowers/train/53/image_03710.jpg
#   inflating: /content/drive/MyDrive/flowers/train/53/image_03711.jpg
#   inflating: /content/drive/MyDrive/flowers/train/53/image_03713.jpg
#   inflating: /content/drive/MyDrive/flowers/train/53/image_03715.jpg
#   inflating: /content/drive/MyDrive/flowers/train/53/image_03716.jpg
#   inflating: /content/drive/MyDrive/flowers/train/53/image_03719.jpg
#   inflating: /content/drive/MyDrive/flowers/train/53/image_03720.jpg
#   inflating: /content/drive/MyDrive/flowers/train/53/image_03721.jpg
#   inflating: /content/drive/MyDrive/flowers/train/53/image_03722.jpg
#   inflating: /content/drive/MyDrive/flowers/train/53/image_03723.jpg
#   inflating: /content/drive/MyDrive/flowers/train/53/image_03725.jpg
#   inflating: /content/drive/MyDrive/flowers/train/53/image_03726.jpg
#   inflating: /content/drive/MyDrive/flowers/train/53/image_03727.jpg
#   inflating: /content/drive/MyDrive/flowers/train/53/image_03728.jpg
#   inflating: /content/drive/MyDrive/flowers/train/53/image_03729.jpg
#   inflating: /content/drive/MyDrive/flowers/train/53/image_03730.jpg
#   inflating: /content/drive/MyDrive/flowers/train/53/image_03731.jpg
#   inflating: /content/drive/MyDrive/flowers/train/53/image_03732.jpg
#   inflating: /content/drive/MyDrive/flowers/train/54/image_05399.jpg
#   inflating: /content/drive/MyDrive/flowers/train/54/image_05400.jpg
#   inflating: /content/drive/MyDrive/flowers/train/54/image_05401.jpg
#   inflating: /content/drive/MyDrive/flowers/train/54/image_05403.jpg
#   inflating: /content/drive/MyDrive/flowers/train/54/image_05404.jpg
#   inflating: /content/drive/MyDrive/flowers/train/54/image_05405.jpg
#   inflating: /content/drive/MyDrive/flowers/train/54/image_05407.jpg
#   inflating: /content/drive/MyDrive/flowers/train/54/image_05408.jpg
#   inflating: /content/drive/MyDrive/flowers/train/54/image_05409.jpg
#   inflating: /content/drive/MyDrive/flowers/train/54/image_05410.jpg
#   inflating: /content/drive/MyDrive/flowers/train/54/image_05412.jpg
#   inflating: /content/drive/MyDrive/flowers/train/54/image_05414.jpg
#   inflating: /content/drive/MyDrive/flowers/train/54/image_05416.jpg
#   inflating: /content/drive/MyDrive/flowers/train/54/image_05418.jpg
#   inflating: /content/drive/MyDrive/flowers/train/54/image_05419.jpg
#   inflating: /content/drive/MyDrive/flowers/train/54/image_05420.jpg
#   inflating: /content/drive/MyDrive/flowers/train/54/image_05421.jpg
#   inflating: /content/drive/MyDrive/flowers/train/54/image_05422.jpg
#   inflating: /content/drive/MyDrive/flowers/train/54/image_05423.jpg
#   inflating: /content/drive/MyDrive/flowers/train/54/image_05424.jpg
#   inflating: /content/drive/MyDrive/flowers/train/54/image_05427.jpg
#   inflating: /content/drive/MyDrive/flowers/train/54/image_05428.jpg
#   inflating: /content/drive/MyDrive/flowers/train/54/image_05429.jpg
#   inflating: /content/drive/MyDrive/flowers/train/54/image_05431.jpg
#   inflating: /content/drive/MyDrive/flowers/train/54/image_05432.jpg
#   inflating: /content/drive/MyDrive/flowers/train/54/image_05433.jpg
#   inflating: /content/drive/MyDrive/flowers/train/54/image_05434.jpg
#   inflating: /content/drive/MyDrive/flowers/train/54/image_05435.jpg
#   inflating: /content/drive/MyDrive/flowers/train/54/image_05436.jpg
#   inflating: /content/drive/MyDrive/flowers/train/54/image_05437.jpg
#   inflating: /content/drive/MyDrive/flowers/train/54/image_05438.jpg
#   inflating: /content/drive/MyDrive/flowers/train/54/image_05439.jpg
#   inflating: /content/drive/MyDrive/flowers/train/54/image_05441.jpg
#   inflating: /content/drive/MyDrive/flowers/train/54/image_05442.jpg
#   inflating: /content/drive/MyDrive/flowers/train/54/image_05443.jpg
#   inflating: /content/drive/MyDrive/flowers/train/54/image_05444.jpg
#   inflating: /content/drive/MyDrive/flowers/train/54/image_05445.jpg
#   inflating: /content/drive/MyDrive/flowers/train/54/image_05446.jpg
#   inflating: /content/drive/MyDrive/flowers/train/54/image_05447.jpg
#   inflating: /content/drive/MyDrive/flowers/train/54/image_05448.jpg
#   inflating: /content/drive/MyDrive/flowers/train/54/image_05450.jpg
#   inflating: /content/drive/MyDrive/flowers/train/54/image_05454.jpg
#   inflating: /content/drive/MyDrive/flowers/train/54/image_05455.jpg
#   inflating: /content/drive/MyDrive/flowers/train/54/image_05456.jpg
#   inflating: /content/drive/MyDrive/flowers/train/54/image_05457.jpg
#   inflating: /content/drive/MyDrive/flowers/train/54/image_05458.jpg
#   inflating: /content/drive/MyDrive/flowers/train/54/image_05459.jpg
#   inflating: /content/drive/MyDrive/flowers/train/55/image_04697.jpg
#   inflating: /content/drive/MyDrive/flowers/train/55/image_04698.jpg
#   inflating: /content/drive/MyDrive/flowers/train/55/image_04699.jpg
#   inflating: /content/drive/MyDrive/flowers/train/55/image_04700.jpg
#   inflating: /content/drive/MyDrive/flowers/train/55/image_04703.jpg
#   inflating: /content/drive/MyDrive/flowers/train/55/image_04704.jpg
#   inflating: /content/drive/MyDrive/flowers/train/55/image_04705.jpg
#   inflating: /content/drive/MyDrive/flowers/train/55/image_04706.jpg
#   inflating: /content/drive/MyDrive/flowers/train/55/image_04708.jpg
#   inflating: /content/drive/MyDrive/flowers/train/55/image_04709.jpg
#   inflating: /content/drive/MyDrive/flowers/train/55/image_04710.jpg
#   inflating: /content/drive/MyDrive/flowers/train/55/image_04711.jpg
#   inflating: /content/drive/MyDrive/flowers/train/55/image_04712.jpg
#   inflating: /content/drive/MyDrive/flowers/train/55/image_04713.jpg
#   inflating: /content/drive/MyDrive/flowers/train/55/image_04714.jpg
#   inflating: /content/drive/MyDrive/flowers/train/55/image_04715.jpg
#   inflating: /content/drive/MyDrive/flowers/train/55/image_04716.jpg
#   inflating: /content/drive/MyDrive/flowers/train/55/image_04717.jpg
#   inflating: /content/drive/MyDrive/flowers/train/55/image_04718.jpg
#   inflating: /content/drive/MyDrive/flowers/train/55/image_04719.jpg
#   inflating: /content/drive/MyDrive/flowers/train/55/image_04721.jpg
#   inflating: /content/drive/MyDrive/flowers/train/55/image_04723.jpg
#   inflating: /content/drive/MyDrive/flowers/train/55/image_04724.jpg
#   inflating: /content/drive/MyDrive/flowers/train/55/image_04725.jpg
#   inflating: /content/drive/MyDrive/flowers/train/55/image_04726.jpg
#   inflating: /content/drive/MyDrive/flowers/train/55/image_04727.jpg
#   inflating: /content/drive/MyDrive/flowers/train/55/image_04728.jpg
#   inflating: /content/drive/MyDrive/flowers/train/55/image_04729.jpg
#   inflating: /content/drive/MyDrive/flowers/train/55/image_04730.jpg
#   inflating: /content/drive/MyDrive/flowers/train/55/image_04732.jpg
#   inflating: /content/drive/MyDrive/flowers/train/55/image_04735.jpg
#   inflating: /content/drive/MyDrive/flowers/train/55/image_04736.jpg
#   inflating: /content/drive/MyDrive/flowers/train/55/image_04737.jpg
#   inflating: /content/drive/MyDrive/flowers/train/55/image_04738.jpg
#   inflating: /content/drive/MyDrive/flowers/train/55/image_04741.jpg
#   inflating: /content/drive/MyDrive/flowers/train/55/image_04743.jpg
#   inflating: /content/drive/MyDrive/flowers/train/55/image_04744.jpg
#   inflating: /content/drive/MyDrive/flowers/train/55/image_04745.jpg
#   inflating: /content/drive/MyDrive/flowers/train/55/image_04746.jpg
#   inflating: /content/drive/MyDrive/flowers/train/55/image_04748.jpg
#   inflating: /content/drive/MyDrive/flowers/train/55/image_04749.jpg
#   inflating: /content/drive/MyDrive/flowers/train/55/image_04750.jpg
#   inflating: /content/drive/MyDrive/flowers/train/55/image_04751.jpg
#   inflating: /content/drive/MyDrive/flowers/train/55/image_04752.jpg
#   inflating: /content/drive/MyDrive/flowers/train/55/image_04754.jpg
#   inflating: /content/drive/MyDrive/flowers/train/55/image_04755.jpg
#   inflating: /content/drive/MyDrive/flowers/train/55/image_04756.jpg
#   inflating: /content/drive/MyDrive/flowers/train/55/image_04757.jpg
#   inflating: /content/drive/MyDrive/flowers/train/55/image_04758.jpg
#   inflating: /content/drive/MyDrive/flowers/train/55/image_04759.jpg
#   inflating: /content/drive/MyDrive/flowers/train/55/image_04761.jpg
#   inflating: /content/drive/MyDrive/flowers/train/55/image_04762.jpg
#   inflating: /content/drive/MyDrive/flowers/train/55/image_04763.jpg
#   inflating: /content/drive/MyDrive/flowers/train/55/image_04764.jpg
#   inflating: /content/drive/MyDrive/flowers/train/55/image_04765.jpg
#   inflating: /content/drive/MyDrive/flowers/train/55/image_04766.jpg
#   inflating: /content/drive/MyDrive/flowers/train/56/image_02753.jpg
#   inflating: /content/drive/MyDrive/flowers/train/56/image_02754.jpg
#   inflating: /content/drive/MyDrive/flowers/train/56/image_02755.jpg
#   inflating: /content/drive/MyDrive/flowers/train/56/image_02756.jpg
#   inflating: /content/drive/MyDrive/flowers/train/56/image_02757.jpg
#   inflating: /content/drive/MyDrive/flowers/train/56/image_02758.jpg
#   inflating: /content/drive/MyDrive/flowers/train/56/image_02759.jpg
#   inflating: /content/drive/MyDrive/flowers/train/56/image_02760.jpg
#   inflating: /content/drive/MyDrive/flowers/train/56/image_02761.jpg
#   inflating: /content/drive/MyDrive/flowers/train/56/image_02762.jpg
#   inflating: /content/drive/MyDrive/flowers/train/56/image_02763.jpg
#   inflating: /content/drive/MyDrive/flowers/train/56/image_02764.jpg
#   inflating: /content/drive/MyDrive/flowers/train/56/image_02765.jpg
#   inflating: /content/drive/MyDrive/flowers/train/56/image_02766.jpg
#   inflating: /content/drive/MyDrive/flowers/train/56/image_02767.jpg
#   inflating: /content/drive/MyDrive/flowers/train/56/image_02768.jpg
#   inflating: /content/drive/MyDrive/flowers/train/56/image_02770.jpg
#   inflating: /content/drive/MyDrive/flowers/train/56/image_02774.jpg
#   inflating: /content/drive/MyDrive/flowers/train/56/image_02775.jpg
#   inflating: /content/drive/MyDrive/flowers/train/56/image_02776.jpg
#   inflating: /content/drive/MyDrive/flowers/train/56/image_02777.jpg
#   inflating: /content/drive/MyDrive/flowers/train/56/image_02778.jpg
#   inflating: /content/drive/MyDrive/flowers/train/56/image_02780.jpg
#   inflating: /content/drive/MyDrive/flowers/train/56/image_02781.jpg
#   inflating: /content/drive/MyDrive/flowers/train/56/image_02782.jpg
#   inflating: /content/drive/MyDrive/flowers/train/56/image_02783.jpg
#   inflating: /content/drive/MyDrive/flowers/train/56/image_02784.jpg
#   inflating: /content/drive/MyDrive/flowers/train/56/image_02786.jpg
#   inflating: /content/drive/MyDrive/flowers/train/56/image_02787.jpg
#   inflating: /content/drive/MyDrive/flowers/train/56/image_02789.jpg
#   inflating: /content/drive/MyDrive/flowers/train/56/image_02790.jpg
#   inflating: /content/drive/MyDrive/flowers/train/56/image_02791.jpg
#   inflating: /content/drive/MyDrive/flowers/train/56/image_02793.jpg
#   inflating: /content/drive/MyDrive/flowers/train/56/image_02794.jpg
#   inflating: /content/drive/MyDrive/flowers/train/56/image_02795.jpg
#   inflating: /content/drive/MyDrive/flowers/train/56/image_02796.jpg
#   inflating: /content/drive/MyDrive/flowers/train/56/image_02797.jpg
#   inflating: /content/drive/MyDrive/flowers/train/56/image_02798.jpg
#   inflating: /content/drive/MyDrive/flowers/train/56/image_02799.jpg
#   inflating: /content/drive/MyDrive/flowers/train/56/image_02800.jpg
#   inflating: /content/drive/MyDrive/flowers/train/56/image_02801.jpg
#   inflating: /content/drive/MyDrive/flowers/train/56/image_02802.jpg
#   inflating: /content/drive/MyDrive/flowers/train/56/image_02803.jpg
#   inflating: /content/drive/MyDrive/flowers/train/56/image_02804.jpg
#   inflating: /content/drive/MyDrive/flowers/train/56/image_02806.jpg
#   inflating: /content/drive/MyDrive/flowers/train/56/image_02807.jpg
#   inflating: /content/drive/MyDrive/flowers/train/56/image_02809.jpg
#   inflating: /content/drive/MyDrive/flowers/train/56/image_02810.jpg
#   inflating: /content/drive/MyDrive/flowers/train/56/image_02811.jpg
#   inflating: /content/drive/MyDrive/flowers/train/56/image_02812.jpg
#   inflating: /content/drive/MyDrive/flowers/train/56/image_02813.jpg
#   inflating: /content/drive/MyDrive/flowers/train/56/image_02814.jpg
#   inflating: /content/drive/MyDrive/flowers/train/56/image_02815.jpg
#   inflating: /content/drive/MyDrive/flowers/train/56/image_02816.jpg
#   inflating: /content/drive/MyDrive/flowers/train/56/image_02817.jpg
#   inflating: /content/drive/MyDrive/flowers/train/56/image_02818.jpg
#   inflating: /content/drive/MyDrive/flowers/train/56/image_02819.jpg
# ...
#   inflating: /content/drive/MyDrive/flowers/valid/78/image_01844.jpg
#   inflating: /content/drive/MyDrive/flowers/valid/78/image_01862.jpg
#   inflating: /content/drive/MyDrive/flowers/valid/78/image_01894.jpg
#   inflating: /content/drive/MyDrive/flowers/valid/78/image_01910.jpg
#   inflating: /content/drive/MyDrive/flowers/valid/78/image_01914.jpg
#   inflating: /content/drive/MyDrive/flowers/valid/78/image_01922.jpg
#   inflating: /content/drive/MyDrive/flowers/valid/78/image_01929.jpg
#   inflating: /content/drive/MyDrive/flowers/valid/78/image_01937.jpg
#   inflating: /content/drive/MyDrive/flowers/valid/78/image_01938.jpg
#   inflating: /content/drive/MyDrive/flowers/valid/78/image_01944.jpg
#   inflating: /content/drive/MyDrive/flowers/valid/78/image_01962.jpg
#   inflating: /content/drive/MyDrive/flowers/valid/79/image_06695.jpg
#   inflating: /content/drive/MyDrive/flowers/valid/79/image_06707.jpg
#   inflating: /content/drive/MyDrive/flowers/valid/79/image_06718.jpg
#   inflating: /content/drive/MyDrive/flowers/valid/79/image_06728.jpg
#   inflating: /content/drive/MyDrive/flowers/valid/8/image_03313.jpg
#   inflating: /content/drive/MyDrive/flowers/valid/8/image_03330.jpg
#   inflating: /content/drive/MyDrive/flowers/valid/8/image_03342.jpg
#   inflating: /content/drive/MyDrive/flowers/valid/8/image_03349.jpg
#   inflating: /content/drive/MyDrive/flowers/valid/8/image_03366.jpg
#   inflating: /content/drive/MyDrive/flowers/valid/80/image_01972.jpg
#   inflating: /content/drive/MyDrive/flowers/valid/80/image_01975.jpg
#   inflating: /content/drive/MyDrive/flowers/valid/80/image_01979.jpg
#   inflating: /content/drive/MyDrive/flowers/valid/80/image_01989.jpg
#   inflating: /content/drive/MyDrive/flowers/valid/80/image_01991.jpg
#   inflating: /content/drive/MyDrive/flowers/valid/80/image_01992.jpg
#   inflating: /content/drive/MyDrive/flowers/valid/80/image_02005.jpg
#   inflating: /content/drive/MyDrive/flowers/valid/80/image_02011.jpg
#   inflating: /content/drive/MyDrive/flowers/valid/80/image_02017.jpg
#   inflating: /content/drive/MyDrive/flowers/valid/80/image_02021.jpg
#   inflating: /content/drive/MyDrive/flowers/valid/80/image_02042.jpg
#   inflating: /content/drive/MyDrive/flowers/valid/80/image_02050.jpg
#   inflating: /content/drive/MyDrive/flowers/valid/81/image_00784.jpg
#   inflating: /content/drive/MyDrive/flowers/valid/81/image_00809.jpg
#   inflating: /content/drive/MyDrive/flowers/valid/81/image_00820.jpg
#   inflating: /content/drive/MyDrive/flowers/valid/81/image_00848.jpg
#   inflating: /content/drive/MyDrive/flowers/valid/81/image_00853.jpg
#   inflating: /content/drive/MyDrive/flowers/valid/81/image_00859.jpg
#   inflating: /content/drive/MyDrive/flowers/valid/81/image_00860.jpg
#   inflating: /content/drive/MyDrive/flowers/valid/81/image_00863.jpg
#   inflating: /content/drive/MyDrive/flowers/valid/81/image_00892.jpg
#   inflating: /content/drive/MyDrive/flowers/valid/81/image_00893.jpg
#   inflating: /content/drive/MyDrive/flowers/valid/81/image_00895.jpg
#   inflating: /content/drive/MyDrive/flowers/valid/81/image_00896.jpg
#   inflating: /content/drive/MyDrive/flowers/valid/81/image_00903.jpg
#   inflating: /content/drive/MyDrive/flowers/valid/81/image_00904.jpg
#   inflating: /content/drive/MyDrive/flowers/valid/81/image_00909.jpg
#   inflating: /content/drive/MyDrive/flowers/valid/81/image_00914.jpg
#   inflating: /content/drive/MyDrive/flowers/valid/81/image_00919.jpg
#   inflating: /content/drive/MyDrive/flowers/valid/81/image_00920.jpg
#   inflating: /content/drive/MyDrive/flowers/valid/82/image_01592.jpg
#   inflating: /content/drive/MyDrive/flowers/valid/82/image_01596.jpg
#   inflating: /content/drive/MyDrive/flowers/valid/82/image_01625.jpg
#   inflating: /content/drive/MyDrive/flowers/valid/82/image_01640.jpg
#   inflating: /content/drive/MyDrive/flowers/valid/82/image_01643.jpg
#   inflating: /content/drive/MyDrive/flowers/valid/82/image_01649.jpg
#   inflating: /content/drive/MyDrive/flowers/valid/82/image_01658.jpg
#   inflating: /content/drive/MyDrive/flowers/valid/82/image_01659.jpg
#   inflating: /content/drive/MyDrive/flowers/valid/82/image_01671.jpg
#   inflating: /content/drive/MyDrive/flowers/valid/82/image_01683.jpg
#   inflating: /content/drive/MyDrive/flowers/valid/82/image_01690.jpg
#   inflating: /content/drive/MyDrive/flowers/valid/82/image_01691.jpg
#   inflating: /content/drive/MyDrive/flowers/valid/82/image_01693.jpg
#   inflating: /content/drive/MyDrive/flowers/valid/83/image_01697.jpg
#   inflating: /content/drive/MyDrive/flowers/valid/83/image_01701.jpg
#   inflating: /content/drive/MyDrive/flowers/valid/83/image_01703.jpg
#   inflating: /content/drive/MyDrive/flowers/valid/83/image_01712.jpg
#   inflating: /content/drive/MyDrive/flowers/valid/83/image_01739.jpg
#   inflating: /content/drive/MyDrive/flowers/valid/83/image_01747.jpg
#   inflating: /content/drive/MyDrive/flowers/valid/83/image_01765.jpg
#   inflating: /content/drive/MyDrive/flowers/valid/83/image_01766.jpg
#   inflating: /content/drive/MyDrive/flowers/valid/83/image_01769.jpg
#   inflating: /content/drive/MyDrive/flowers/valid/83/image_01780.jpg
#   inflating: /content/drive/MyDrive/flowers/valid/83/image_01787.jpg
#   inflating: /content/drive/MyDrive/flowers/valid/83/image_01811.jpg
#   inflating: /content/drive/MyDrive/flowers/valid/83/image_01817.jpg
#   inflating: /content/drive/MyDrive/flowers/valid/84/image_02567.jpg
#   inflating: /content/drive/MyDrive/flowers/valid/84/image_02574.jpg
#   inflating: /content/drive/MyDrive/flowers/valid/84/image_02582.jpg
#   inflating: /content/drive/MyDrive/flowers/valid/84/image_02591.jpg
#   inflating: /content/drive/MyDrive/flowers/valid/84/image_02598.jpg
#   inflating: /content/drive/MyDrive/flowers/valid/84/image_02604.jpg
#   inflating: /content/drive/MyDrive/flowers/valid/84/image_02610.jpg
#   inflating: /content/drive/MyDrive/flowers/valid/84/image_02621.jpg
#   inflating: /content/drive/MyDrive/flowers/valid/84/image_02635.jpg
#   inflating: /content/drive/MyDrive/flowers/valid/84/image_02637.jpg
#   inflating: /content/drive/MyDrive/flowers/valid/85/image_04799.jpg
#   inflating: /content/drive/MyDrive/flowers/valid/85/image_04804.jpg
#   inflating: /content/drive/MyDrive/flowers/valid/85/image_04809.jpg
#   inflating: /content/drive/MyDrive/flowers/valid/85/image_04817.jpg
#   inflating: /content/drive/MyDrive/flowers/valid/85/image_04818.jpg
#   inflating: /content/drive/MyDrive/flowers/valid/86/image_02887.jpg
#   inflating: /content/drive/MyDrive/flowers/valid/86/image_02891.jpg
#   inflating: /content/drive/MyDrive/flowers/valid/86/image_02901.jpg
#   inflating: /content/drive/MyDrive/flowers/valid/86/image_02906.jpg
#   inflating: /content/drive/MyDrive/flowers/valid/86/image_02909.jpg
#   inflating: /content/drive/MyDrive/flowers/valid/87/image_05484.jpg
#   inflating: /content/drive/MyDrive/flowers/valid/87/image_05487.jpg
#   inflating: /content/drive/MyDrive/flowers/valid/87/image_05502.jpg
#   inflating: /content/drive/MyDrive/flowers/valid/87/image_05507.jpg
#   inflating: /content/drive/MyDrive/flowers/valid/87/image_05508.jpg
#   inflating: /content/drive/MyDrive/flowers/valid/87/image_05520.jpg
#   inflating: /content/drive/MyDrive/flowers/valid/88/image_00459.jpg
#   inflating: /content/drive/MyDrive/flowers/valid/88/image_00461.jpg
#   inflating: /content/drive/MyDrive/flowers/valid/88/image_00489.jpg
#   inflating: /content/drive/MyDrive/flowers/valid/88/image_00502.jpg
#   inflating: /content/drive/MyDrive/flowers/valid/88/image_00508.jpg
#   inflating: /content/drive/MyDrive/flowers/valid/88/image_00509.jpg
#   inflating: /content/drive/MyDrive/flowers/valid/88/image_00512.jpg
#   inflating: /content/drive/MyDrive/flowers/valid/88/image_00516.jpg
#   inflating: /content/drive/MyDrive/flowers/valid/88/image_00518.jpg
#   inflating: /content/drive/MyDrive/flowers/valid/88/image_00531.jpg
#   inflating: /content/drive/MyDrive/flowers/valid/88/image_00533.jpg
#   inflating: /content/drive/MyDrive/flowers/valid/88/image_00539.jpg
#   inflating: /content/drive/MyDrive/flowers/valid/88/image_00542.jpg
#   inflating: /content/drive/MyDrive/flowers/valid/88/image_00544.jpg
#   inflating: /content/drive/MyDrive/flowers/valid/88/image_00545.jpg
#   inflating: /content/drive/MyDrive/flowers/valid/88/image_00546.jpg
#   inflating: /content/drive/MyDrive/flowers/valid/88/image_00547.jpg
#   inflating: /content/drive/MyDrive/flowers/valid/88/image_00554.jpg
#   inflating: /content/drive/MyDrive/flowers/valid/88/image_00556.jpg
#   inflating: /content/drive/MyDrive/flowers/valid/88/image_00574.jpg
#   inflating: /content/drive/MyDrive/flowers/valid/88/image_00577.jpg
#   inflating: /content/drive/MyDrive/flowers/valid/88/image_00585.jpg
#   inflating: /content/drive/MyDrive/flowers/valid/88/image_00593.jpg
#   inflating: /content/drive/MyDrive/flowers/valid/88/image_00595.jpg
#   inflating: /content/drive/MyDrive/flowers/valid/88/image_00597.jpg
#   inflating: /content/drive/MyDrive/flowers/valid/89/image_00623.jpg
#   inflating: /content/drive/MyDrive/flowers/valid/89/image_00624.jpg
#   inflating: /content/drive/MyDrive/flowers/valid/89/image_00627.jpg
#   inflating: /content/drive/MyDrive/flowers/valid/89/image_00640.jpg
#   inflating: /content/drive/MyDrive/flowers/valid/89/image_00652.jpg
#   inflating: /content/drive/MyDrive/flowers/valid/89/image_00691.jpg
#   inflating: /content/drive/MyDrive/flowers/valid/89/image_00692.jpg
#   inflating: /content/drive/MyDrive/flowers/valid/89/image_00696.jpg
#   inflating: /content/drive/MyDrive/flowers/valid/89/image_00730.jpg
#   inflating: /content/drive/MyDrive/flowers/valid/89/image_00741.jpg
#   inflating: /content/drive/MyDrive/flowers/valid/89/image_00746.jpg
#   inflating: /content/drive/MyDrive/flowers/valid/89/image_00749.jpg
#   inflating: /content/drive/MyDrive/flowers/valid/89/image_00752.jpg
#   inflating: /content/drive/MyDrive/flowers/valid/89/image_00759.jpg
#   inflating: /content/drive/MyDrive/flowers/valid/89/image_00763.jpg
#   inflating: /content/drive/MyDrive/flowers/valid/89/image_00764.jpg
#   inflating: /content/drive/MyDrive/flowers/valid/9/image_06398.jpg
#   inflating: /content/drive/MyDrive/flowers/valid/9/image_06414.jpg
#   inflating: /content/drive/MyDrive/flowers/valid/9/image_06420.jpg
#   inflating: /content/drive/MyDrive/flowers/valid/90/image_04402.jpg
#   inflating: /content/drive/MyDrive/flowers/valid/90/image_04403.jpg
#   inflating: /content/drive/MyDrive/flowers/valid/91/image_04829.jpg
#   inflating: /content/drive/MyDrive/flowers/valid/91/image_04835.jpg
#   inflating: /content/drive/MyDrive/flowers/valid/91/image_04843.jpg
#   inflating: /content/drive/MyDrive/flowers/valid/91/image_04844.jpg
#   inflating: /content/drive/MyDrive/flowers/valid/91/image_04848.jpg
#   inflating: /content/drive/MyDrive/flowers/valid/91/image_04854.jpg
#   inflating: /content/drive/MyDrive/flowers/valid/91/image_04872.jpg
#   inflating: /content/drive/MyDrive/flowers/valid/91/image_04878.jpg
#   inflating: /content/drive/MyDrive/flowers/valid/91/image_08059.jpg
#   inflating: /content/drive/MyDrive/flowers/valid/92/image_03063.jpg
#   inflating: /content/drive/MyDrive/flowers/valid/92/image_03065.jpg
#   inflating: /content/drive/MyDrive/flowers/valid/93/image_06024.jpg
#   inflating: /content/drive/MyDrive/flowers/valid/93/image_06044.jpg
#   inflating: /content/drive/MyDrive/flowers/valid/93/image_06048.jpg
#   inflating: /content/drive/MyDrive/flowers/valid/93/image_07302.jpg
#   inflating: /content/drive/MyDrive/flowers/valid/93/image_07303.jpg
#   inflating: /content/drive/MyDrive/flowers/valid/93/image_08113.jpg
#   inflating: /content/drive/MyDrive/flowers/valid/94/image_07317.jpg
#   inflating: /content/drive/MyDrive/flowers/valid/94/image_07325.jpg
#   inflating: /content/drive/MyDrive/flowers/valid/94/image_07360.jpg
#   inflating: /content/drive/MyDrive/flowers/valid/94/image_07372.jpg
#   inflating: /content/drive/MyDrive/flowers/valid/94/image_07381.jpg
#   inflating: /content/drive/MyDrive/flowers/valid/94/image_07382.jpg
#   inflating: /content/drive/MyDrive/flowers/valid/94/image_07385.jpg
#   inflating: /content/drive/MyDrive/flowers/valid/94/image_07392.jpg
#   inflating: /content/drive/MyDrive/flowers/valid/94/image_07393.jpg
#   inflating: /content/drive/MyDrive/flowers/valid/94/image_07408.jpg
#   inflating: /content/drive/MyDrive/flowers/valid/94/image_07418.jpg
#   inflating: /content/drive/MyDrive/flowers/valid/94/image_07428.jpg
#   inflating: /content/drive/MyDrive/flowers/valid/94/image_07435.jpg
#   inflating: /content/drive/MyDrive/flowers/valid/94/image_07449.jpg
#   inflating: /content/drive/MyDrive/flowers/valid/95/image_07471.jpg
#   inflating: /content/drive/MyDrive/flowers/valid/95/image_07475.jpg
#   inflating: /content/drive/MyDrive/flowers/valid/95/image_07484.jpg
#   inflating: /content/drive/MyDrive/flowers/valid/95/image_07485.jpg
#   inflating: /content/drive/MyDrive/flowers/valid/95/image_07502.jpg
#   inflating: /content/drive/MyDrive/flowers/valid/95/image_07510.jpg
#   inflating: /content/drive/MyDrive/flowers/valid/95/image_07512.jpg
#   inflating: /content/drive/MyDrive/flowers/valid/95/image_07513.jpg
#   inflating: /content/drive/MyDrive/flowers/valid/95/image_07575.jpg
#   inflating: /content/drive/MyDrive/flowers/valid/95/image_07580.jpg
#   inflating: /content/drive/MyDrive/flowers/valid/95/image_07581.jpg
#   inflating: /content/drive/MyDrive/flowers/valid/95/image_07585.jpg
#   inflating: /content/drive/MyDrive/flowers/valid/95/image_07588.jpg
#   inflating: /content/drive/MyDrive/flowers/valid/96/image_07605.jpg
#   inflating: /content/drive/MyDrive/flowers/valid/96/image_07609.jpg
#   inflating: /content/drive/MyDrive/flowers/valid/96/image_07613.jpg
#   inflating: /content/drive/MyDrive/flowers/valid/96/image_07653.jpg
#   inflating: /content/drive/MyDrive/flowers/valid/96/image_07656.jpg
#   inflating: /content/drive/MyDrive/flowers/valid/96/image_07658.jpg
#   inflating: /content/drive/MyDrive/flowers/valid/96/image_07662.jpg
#   inflating: /content/drive/MyDrive/flowers/valid/96/image_07669.jpg
#   inflating: /content/drive/MyDrive/flowers/valid/96/image_07670.jpg
#   inflating: /content/drive/MyDrive/flowers/valid/96/image_07677.jpg
#   inflating: /content/drive/MyDrive/flowers/valid/97/image_07697.jpg
#   inflating: /content/drive/MyDrive/flowers/valid/97/image_07699.jpg
#   inflating: /content/drive/MyDrive/flowers/valid/97/image_07718.jpg
#   inflating: /content/drive/MyDrive/flowers/valid/97/image_07723.jpg
#   inflating: /content/drive/MyDrive/flowers/valid/97/image_07727.jpg
#   inflating: /content/drive/MyDrive/flowers/valid/97/image_07739.jpg
#   inflating: /content/drive/MyDrive/flowers/valid/97/image_07745.jpg
#   inflating: /content/drive/MyDrive/flowers/valid/98/image_07757.jpg
#   inflating: /content/drive/MyDrive/flowers/valid/98/image_07764.jpg
#   inflating: /content/drive/MyDrive/flowers/valid/98/image_07766.jpg
#   inflating: /content/drive/MyDrive/flowers/valid/98/image_07769.jpg
#   inflating: /content/drive/MyDrive/flowers/valid/98/image_07778.jpg
#   inflating: /content/drive/MyDrive/flowers/valid/98/image_07792.jpg
#   inflating: /content/drive/MyDrive/flowers/valid/98/image_07796.jpg
#   inflating: /content/drive/MyDrive/flowers/valid/98/image_07810.jpg
#   inflating: /content/drive/MyDrive/flowers/valid/98/image_07820.jpg
#   inflating: /content/drive/MyDrive/flowers/valid/98/image_07827.jpg
#   inflating: /content/drive/MyDrive/flowers/valid/99/image_07860.jpg
#   inflating: /content/drive/MyDrive/flowers/valid/99/image_07862.jpg
#   inflating: /content/drive/MyDrive/flowers/valid/99/image_07869.jpg
#   inflating: /content/drive/MyDrive/flowers/valid/99/image_07873.jpg
#   inflating: /content/drive/MyDrive/flowers/valid/99/image_07875.jpg
#   inflating: /content/drive/MyDrive/flowers/valid/99/image_08063.jpg

# %%
# Before you proceed, update the PATH
import os
os.environ['PATH'] = f"{os.environ['PATH']}:/root/.local/bin"
os.environ['PATH'] = f"{os.environ['PATH']}:/opt/conda/lib/python3.6/site-packages"
# Restart the Kernel at this point.

# %%
# Do not execute the commands below unless you have restart the Kernel after updating the PATH.
# !python -m pip install torch==1.0.0
# Out:
# ERROR: Could not find a version that satisfies the requirement torch==1.0.0 (from versions: 1.11.0, 1.12.0, 1.12.1, 1.13.0, 1.13.1, 2.0.0, 2.0.1, 2.1.0, 2.1.1, 2.1.2)
# ERROR: No matching distribution found for torch==1.0.0

# %%
# Check torch version and CUDA status if GPU is enabled.
import torch
print(torch.__version__)
print(torch.cuda.is_available()) # Should return True when GPU is enabled.
# Out:
# 2.1.0+cu121
# True

# %% [markdown]
# # Developing an AI application
#
# Going forward, AI algorithms will be incorporated into more and more everyday applications. For example, you might want to include an image classifier in a smart phone app. To do this, you'd use a deep learning model trained on hundreds of thousands of images as part of the overall application architecture. A large part of software development in the future will be using these types of models as common parts of applications.
#
# In this project, you'll train an image classifier to recognize different species of flowers. You can imagine using something like this in a phone app that tells you the name of the flower your camera is looking at. In practice you'd train this classifier, then export it for use in your application. We'll be using [this dataset](http://www.robots.ox.ac.uk/~vgg/data/flowers/102/index.html) of 102 flower categories, you can see a few examples below.
#
# <img src='assets/Flowers.png' width=500px>
#
# The project is broken down into multiple steps:
#
# * Load and preprocess the image dataset
# * Train the image classifier on your dataset
# * Use the trained classifier to predict image content
#
# We'll lead you through each part which you'll implement in Python.
#
# When you've completed this project, you'll have an application that can be trained on any set of labeled images. Here your network will be learning about flowers and end up as a command line application. But, what you do with your new skills depends on your imagination and effort in building a dataset. For example, imagine an app where you take a picture of a car, it tells you what the make and model is, then looks up information about it. Go build your own dataset and make something new.
#
# First up is importing the packages you'll need. It's good practice to keep all the imports at the beginning of your code. As you work through this notebook and find you need to import a package, make sure to add the import up here.

# %%
# Imports here
import numpy as np
import matplotlib.pyplot as plt

import torchvision
from torchvision import datasets, transforms, models

import torch
from torch import nn, optim
from torch.autograd import Variable
import torch.nn.functional as F

from collections import OrderedDict
import random, os
from PIL import Image

# %% [markdown]
# ## Load the data
#
# Here you'll use `torchvision` to load the data ([documentation](http://pytorch.org/docs/0.3.0/torchvision/index.html)). The data should be included alongside this notebook, otherwise you can [download it here](https://s3.amazonaws.com/content.udacity-data.com/nd089/flower_data.tar.gz).

# %% [markdown]
# If you do not find the `flowers/` dataset in the current directory, **/workspace/home/aipnd-project/**, you can download it using the following commands.
#
# ```bash
# !wget 'https://s3.amazonaws.com/content.udacity-data.com/nd089/flower_data.tar.gz'
# !unlink flowers
# !mkdir flowers && tar -xzf flower_data.tar.gz -C flowers
# ```

# %% [markdown]
# ## Data Description
# The dataset is split into three parts, training, validation, and testing. For the training, you'll want to apply transformations such as random scaling, cropping, and flipping. This will help the network generalize leading to better performance. You'll also need to make sure the input data is resized to 224x224 pixels as required by the pre-trained networks.
#
# The validation and testing sets are used to measure the model's performance on data it hasn't seen yet. For this you don't want any scaling or rotation transformations, but you'll need to resize then crop the images to the appropriate size.
#
# The pre-trained networks you'll use were trained on the ImageNet dataset where each color channel was normalized separately. For all three sets you'll need to normalize the means and standard deviations of the images to what the network expects. For the means, it's `[0.485, 0.456, 0.406]` and for the standard deviations `[0.229, 0.224, 0.225]`, calculated from the ImageNet images.  These values will shift each color channel to be centered at 0 and range from -1 to 1.

# %%
data_dir = '/content/drive/MyDrive/flowers'
train_dir = data_dir + '/train'
valid_dir = data_dir + '/valid'
test_dir = data_dir + '/test'

# %%
# Defining the transforms for the training, validation, and testing sets
train_transform = transforms.Compose([transforms.RandomRotation(50),
                                              transforms.RandomResizedCrop(224),
                                              transforms.RandomHorizontalFlip(),
                                              transforms.ToTensor(),
                                              transforms.Normalize([0.485, 0.456, 0.406],
                                                                   [0.229, 0.224, 0.225])])

valid_transform = transforms.Compose([transforms.Resize(255),
                                                transforms.CenterCrop(224),
                                                transforms.ToTensor(),
                                                transforms.Normalize([0.485, 0.456, 0.406],
                                                                     [0.229, 0.224, 0.225])])

test_transform = transforms.Compose([transforms.Resize(255),
                                             transforms.CenterCrop(224),
                                             transforms.ToTensor(),
                                             transforms.Normalize([0.485, 0.456, 0.406],
                                                                  [0.229, 0.224, 0.225])])
# Loading the datasets with ImageFolder
train_data = datasets.ImageFolder(train_dir, transform = train_transform)
valid_data = datasets.ImageFolder(valid_dir, transform = valid_transform)
test_data = datasets.ImageFolder(test_dir, transform = test_transform)


# Using the image datasets and the trainforms, define the dataloaders
trainloader = torch.utils.data.DataLoader(train_data, batch_size = 64, shuffle = True)
validloader = torch.utils.data.DataLoader(valid_data, batch_size = 64)
testloader = torch.utils.data.DataLoader(test_data, batch_size = 64)

# %% [markdown]
# ### Label mapping
#
# You'll also need to load in a mapping from category label to category name. You can find this in the file `cat_to_name.json`. It's a JSON object which you can read in with the [`json` module](https://docs.python.org/2/library/json.html). This will give you a dictionary mapping the integer encoded categories to the actual names of the flowers.

# %%
import json

with open('/content/drive/MyDrive/cat_to_name.json', 'r') as f:
    cat_to_name = json.load(f)

# %% [markdown]
# # Building and training the classifier
#
# Now that the data is ready, it's time to build and train the classifier. As usual, you should use one of the pretrained models from `torchvision.models` to get the image features. Build and train a new feed-forward classifier using those features.
#
# We're going to leave this part up to you. Refer to [the rubric](https://review.udacity.com/#!/rubrics/1663/view) for guidance on successfully completing this section. Things you'll need to do:
#
# * Load a [pre-trained network](http://pytorch.org/docs/master/torchvision/models.html) (If you need a starting point, the VGG networks work great and are straightforward to use)
# * Define a new, untrained feed-forward network as a classifier, using ReLU activations and dropout
# * Train the classifier layers using backpropagation using the pre-trained network to get the features
# * Track the loss and accuracy on the validation set to determine the best hyperparameters
#
# We've left a cell open for you below, but use as many as you need. Our advice is to break the problem up into smaller parts you can run separately. Check that each part is doing what you expect, then move on to the next. You'll likely find that as you work through each part, you'll need to go back and modify your previous code. This is totally normal!
#
# When training make sure you're updating only the weights of the feed-forward network. You should be able to get the validation accuracy above 70% if you build everything right. Make sure to try different hyperparameters (learning rate, units in the classifier, epochs, etc) to find the best model. Save those hyperparameters to use as default values in the next part of the project.
#
# One last important tip if you're using the workspace to run your code: To avoid having your workspace disconnect during the long-running tasks in this notebook, please read in the earlier page in this lesson called Intro to
# GPU Workspaces about Keeping Your Session Active. You'll want to include code from the workspace_utils.py module.
#
# ## Note for Workspace users:
# If your network is over 1 GB when saved as a checkpoint, there might be issues with saving backups in your workspace. Typically this happens with wide dense layers after the convolutional layers. If your saved checkpoint is larger than 1 GB (you can open a terminal and check with `ls -lh`), you should reduce the size of your hidden layers and train again.

# %%
# Building and training the network
model = models.vgg16(pretrained=True)
model
# Out:
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=VGG16_Weights.IMAGENET1K_V1`. You can also use `weights=VGG16_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# VGG(
#   (features): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU(inplace=True)
#     (2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU(inplace=True)
#     (4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (5): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (6): ReLU(inplace=True)
#     (7): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (8): ReLU(inplace=True)
#     (9): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (10): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (11): ReLU(inplace=True)
#     (12): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (13): ReLU(inplace=True)
#     (14): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (15): ReLU(inplace=True)
#     (16): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (17): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (18): ReLU(inplace=True)
#     (19): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (20): ReLU(inplace=True)
#     (21): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (22): ReLU(inplace=True)
#     (23): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (24): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (25): ReLU(inplace=True)
#     (26): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (27): ReLU(inplace=True)
#     (28): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (29): ReLU(inplace=True)
#     (30): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(7, 7))
#   (classifier): Sequential(
#     (0): Linear(in_features=25088, out_features=4096, bias=True)
#     (1): ReLU(inplace=True)
#     (2): Dropout(p=0.5, inplace=False)
#     (3): Linear(in_features=4096, out_features=4096, bias=True)
#     (4): ReLU(inplace=True)
#     (5): Dropout(p=0.5, inplace=False)
#     (6): Linear(in_features=4096, out_features=1000, bias=True)
#   )
# )

# %%
# Freezing the gradient of the parameter
for param in model.parameters():
    param.requires_grad = False

classifier = nn.Sequential(
          nn.Linear(25088, 512),
          nn.ReLU(),
          nn.Dropout(p=0.2),
          nn.Linear(512, 256),
          nn.ReLU(),
          nn.Dropout(p=0.2),
          nn.Linear(256, 102),
          nn.LogSoftmax(dim = 1)
        )

model.classifier = classifier

# %%
# Check if the gpu is available
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# Training the neural network
criterion = nn.NLLLoss()
optimizer = optim.Adam(model.classifier.parameters(), lr = 0.0025)

model.to(device)
# Out:
# VGG(
#   (features): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU(inplace=True)
#     (2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU(inplace=True)
#     (4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (5): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (6): ReLU(inplace=True)
#     (7): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (8): ReLU(inplace=True)
#     (9): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (10): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (11): ReLU(inplace=True)
#     (12): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (13): ReLU(inplace=True)
#     (14): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (15): ReLU(inplace=True)
#     (16): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (17): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (18): ReLU(inplace=True)
#     (19): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (20): ReLU(inplace=True)
#     (21): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (22): ReLU(inplace=True)
#     (23): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (24): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (25): ReLU(inplace=True)
#     (26): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (27): ReLU(inplace=True)
#     (28): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (29): ReLU(inplace=True)
#     (30): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(7, 7))
#   (classifier): Sequential(
#     (0): Linear(in_features=25088, out_features=512, bias=True)
#     (1): ReLU()
#     (2): Dropout(p=0.2, inplace=False)
#     (3): Linear(in_features=512, out_features=256, bias=True)
#     (4): ReLU()
#     (5): Dropout(p=0.2, inplace=False)
#     (6): Linear(in_features=256, out_features=102, bias=True)
#     (7): LogSoftmax(dim=1)
#   )
# )

# %%
epochs = 4
steps = 0
print_every = 10
train_loss = 0


for epoch in range(epochs):
    print('Epoch {}/{}'.format(epoch +1, epochs))

    for inputs, labels in trainloader:
        steps += 1
        inputs, labels = inputs.to(device), labels.to(device)

        optimizer.zero_grad()

        logps = model.forward(inputs)
        loss = criterion(logps, labels)
        loss.backward()
        optimizer.step()

        train_loss += loss.item()

        if steps % print_every == 0:
            valid_loss = 0
            valid_accuracy = 0

            model.eval()

            with torch.no_grad():
                for inputs, labels in validloader:
                    inputs, labels = inputs.to(device), labels.to(device)

                    logps = model.forward(inputs)
                    batch_loss = criterion(logps, labels)
                    valid_loss += batch_loss.item()

                    # Calculate validation accuracy
                    ps = torch.exp(logps)
                    top_p, top_class = ps.topk(1, dim=1)
                    equals = top_class == labels.view(*top_class.shape)
                    valid_accuracy += torch.mean(equals.type(torch.FloatTensor)).item()

            print(f"Train loss: {train_loss/print_every:.3f}", f"Valid loss: {valid_loss/len(validloader):.3f}", f"Valid accuracy: {valid_accuracy/len(validloader):.3f}")
            print(' ')



            train_loss = 0

            model.train()
# Out:
# Epoch 1/4
# Train loss: 4.806 Valid loss: 4.353 Valid accuracy: 0.046
#
# Train loss: 4.366 Valid loss: 3.878 Valid accuracy: 0.143
#
# Train loss: 3.824 Valid loss: 3.289 Valid accuracy: 0.261
#
# Train loss: 3.356 Valid loss: 2.688 Valid accuracy: 0.372
#
# Train loss: 3.216 Valid loss: 2.497 Valid accuracy: 0.395
#
# Train loss: 2.787 Valid loss: 2.149 Valid accuracy: 0.462
#
# Train loss: 2.705 Valid loss: 1.981 Valid accuracy: 0.487
#
# Train loss: 2.584 Valid loss: 1.707 Valid accuracy: 0.546
#
# Train loss: 2.392 Valid loss: 1.614 Valid accuracy: 0.561
#
# Train loss: 2.509 Valid loss: 1.664 Valid accuracy: 0.551
#
# Epoch 2/4
# Train loss: 2.209 Valid loss: 1.500 Valid accuracy: 0.590
#
# Train loss: 2.158 Valid loss: 1.483 Valid accuracy: 0.591
#
# Train loss: 2.242 Valid loss: 1.396 Valid accuracy: 0.634
#
# Train loss: 2.046 Valid loss: 1.308 Valid accuracy: 0.639
#
# Train loss: 1.883 Valid loss: 1.248 Valid accuracy: 0.657
#
# Train loss: 2.033 Valid loss: 1.173 Valid accuracy: 0.672
#
# Train loss: 1.987 Valid loss: 1.273 Valid accuracy: 0.630
#
# Train loss: 1.919 Valid loss: 1.293 Valid accuracy: 0.633
#
# Train loss: 1.952 Valid loss: 1.248 Valid accuracy: 0.660
#
# Train loss: 1.867 Valid loss: 1.181 Valid accuracy: 0.655
#
# Epoch 3/4
# Train loss: 1.820 Valid loss: 1.154 Valid accuracy: 0.690
#
# Train loss: 1.843 Valid loss: 1.241 Valid accuracy: 0.646
#
# Train loss: 1.819 Valid loss: 1.135 Valid accuracy: 0.685
#
# Train loss: 1.797 Valid loss: 1.028 Valid accuracy: 0.713
#
# Train loss: 1.665 Valid loss: 1.064 Valid accuracy: 0.695
#
# Train loss: 1.675 Valid loss: 1.047 Valid accuracy: 0.711
#
# Train loss: 1.603 Valid loss: 1.032 Valid accuracy: 0.708
#
# Train loss: 1.655 Valid loss: 0.947 Valid accuracy: 0.738
#
# Train loss: 1.798 Valid loss: 0.978 Valid accuracy: 0.730
#
# Train loss: 1.684 Valid loss: 0.967 Valid accuracy: 0.724
#
# Epoch 4/4
# Train loss: 1.716 Valid loss: 1.028 Valid accuracy: 0.711
#
# Train loss: 1.654 Valid loss: 1.074 Valid accuracy: 0.710
#
# Train loss: 1.634 Valid loss: 0.974 Valid accuracy: 0.727
#
# Train loss: 1.693 Valid loss: 0.914 Valid accuracy: 0.755
#
# Train loss: 1.514 Valid loss: 0.952 Valid accuracy: 0.736
#
# Train loss: 1.584 Valid loss: 0.945 Valid accuracy: 0.740
#
# Train loss: 1.499 Valid loss: 1.005 Valid accuracy: 0.732
#
# Train loss: 1.561 Valid loss: 0.914 Valid accuracy: 0.756
#
# Train loss: 1.661 Valid loss: 0.941 Valid accuracy: 0.737
#
# Train loss: 1.499 Valid loss: 0.911 Valid accuracy: 0.757
#
# Train loss: 1.578 Valid loss: 0.826 Valid accuracy: 0.769

# %% [markdown]
# ## Testing your network
#
# It's good practice to test your trained network on test data, images the network has never seen either in training or validation. This will give you a good estimate for the model's performance on completely new images. Run the test images through the network and measure the accuracy, the same way you did validation. You should be able to reach around 70% accuracy on the test set if the model has been trained well.

# %%
# Validation on the test set
test_loss = 0
test_accuracy = 0
model.eval() # Model evaluation
with torch.no_grad():
    for inputs, labels in testloader:
        inputs, labels = inputs.to(device), labels.to(device)

        logps = model.forward(inputs)
        batch_loss = criterion(logps, labels)
        test_loss += batch_loss.item()

        # Calculate accuracy of test set
        ps = torch.exp(logps)
        top_p, top_class = ps.topk(1, dim=1)
        equals = top_class == labels.view(*top_class.shape)
        test_accuracy += torch.mean(equals.type(torch.FloatTensor)).item()

print(f"Test loss: {test_loss/len(testloader):.3f}, "
      f"Test accuracy: {100*(test_accuracy/len(testloader)):.3f}%")
running_loss = 0
# Out:
# Test loss: 0.889, Test accuracy: 76.850%

# %% [markdown]
# ## Save the checkpoint
#
# Now that your network is trained, save the model so you can load it later for making predictions. You probably want to save other things such as the mapping of classes to indices which you get from one of the image datasets: `image_datasets['train'].class_to_idx`. You can attach this to the model as an attribute which makes inference easier later on.
#
# ```model.class_to_idx = image_datasets['train'].class_to_idx```
#
# Remember that you'll want to completely rebuild the model later so you can use it for inference. Make sure to include any information you need in the checkpoint. If you want to load the model and keep training, you'll want to save the number of epochs as well as the optimizer state, `optimizer.state_dict`. You'll likely want to use this trained model in the next part of the project, so best to save it now.

# %%
# Saving the checkpoint

checkpoint = {
    'epochs': epochs,
    'learning_rate': 0.0025,
    'model_state_dict': model.state_dict(),
    'optimizer_state_dict': optimizer.state_dict(),
    'criterion_state_dict': criterion.state_dict(),
    'class_to_idx': train_data.class_to_idx
}

torch.save(checkpoint, 'checkpoint.pth')

# %% [markdown]
# ## Loading the checkpoint
#
# At this point it's good to write a function that can load a checkpoint and rebuild the model. That way you can come back to this project and keep working on it without having to retrain the network.

# %%
# Writing a function that loads a checkpoint and rebuilds the model
def load_checkpoint(filepath):
    model = models.vgg16(pretrained = True)

    for param in model.parameters():
        param.requires_grad = False

    classifier = nn.Sequential(
          nn.Linear(25088, 512),
          nn.ReLU(),
          nn.Dropout(p=0.2),
          nn.Linear(512, 256),
          nn.ReLU(),
          nn.Dropout(p=0.2),
          nn.Linear(256, 102),
          nn.LogSoftmax(dim = 1))

    model.classifier = classifier

    checkpoint = torch.load(filepath)
    model.load_state_dict(checkpoint['model_state_dict'])
    epochs = checkpoint['epochs']
    learning_rate = checkpoint['learning_rate']

    model.class_to_idx = checkpoint['class_to_idx']

    return model, epochs, learning_rate

# %%
model, epochs, learning_rate = load_checkpoint('checkpoint.pth')
model
# Out:
# VGG(
#   (features): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU(inplace=True)
#     (2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU(inplace=True)
#     (4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (5): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (6): ReLU(inplace=True)
#     (7): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (8): ReLU(inplace=True)
#     (9): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (10): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (11): ReLU(inplace=True)
#     (12): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (13): ReLU(inplace=True)
#     (14): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (15): ReLU(inplace=True)
#     (16): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (17): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (18): ReLU(inplace=True)
#     (19): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (20): ReLU(inplace=True)
#     (21): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (22): ReLU(inplace=True)
#     (23): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (24): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (25): ReLU(inplace=True)
#     (26): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (27): ReLU(inplace=True)
#     (28): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (29): ReLU(inplace=True)
#     (30): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(7, 7))
#   (classifier): Sequential(
#     (0): Linear(in_features=25088, out_features=512, bias=True)
#     (1): ReLU()
#     (2): Dropout(p=0.2, inplace=False)
#     (3): Linear(in_features=512, out_features=256, bias=True)
#     (4): ReLU()
#     (5): Dropout(p=0.2, inplace=False)
#     (6): Linear(in_features=256, out_features=102, bias=True)
#     (7): LogSoftmax(dim=1)
#   )
# )

# %% [markdown]
# # Inference for classification
#
# Now you'll write a function to use a trained network for inference. That is, you'll pass an image into the network and predict the class of the flower in the image. Write a function called `predict` that takes an image and a model, then returns the top $K$ most likely classes along with the probabilities. It should look like
#
# ```python
# probs, classes = predict(image_path, model)
# print(probs)
# print(classes)
# > [ 0.01558163  0.01541934  0.01452626  0.01443549  0.01407339]
# > ['70', '3', '45', '62', '55']
# ```
#
# First you'll need to handle processing the input image such that it can be used in your network.
#
# ## Image Preprocessing
#
# You'll want to use `PIL` to load the image ([documentation](https://pillow.readthedocs.io/en/latest/reference/Image.html)). It's best to write a function that preprocesses the image so it can be used as input for the model. This function should process the images in the same manner used for training.
#
# First, resize the images where the shortest side is 256 pixels, keeping the aspect ratio. This can be done with the [`thumbnail`](http://pillow.readthedocs.io/en/3.1.x/reference/Image.html#PIL.Image.Image.thumbnail) or [`resize`](http://pillow.readthedocs.io/en/3.1.x/reference/Image.html#PIL.Image.Image.thumbnail) methods. Then you'll need to crop out the center 224x224 portion of the image.
#
# Color channels of images are typically encoded as integers 0-255, but the model expected floats 0-1. You'll need to convert the values. It's easiest with a Numpy array, which you can get from a PIL image like so `np_image = np.array(pil_image)`.
#
# As before, the network expects the images to be normalized in a specific way. For the means, it's `[0.485, 0.456, 0.406]` and for the standard deviations `[0.229, 0.224, 0.225]`. You'll want to subtract the means from each color channel, then divide by the standard deviation.
#
# And finally, PyTorch expects the color channel to be the first dimension but it's the third dimension in the PIL image and Numpy array. You can reorder dimensions using [`ndarray.transpose`](https://docs.scipy.org/doc/numpy-1.13.0/reference/generated/numpy.ndarray.transpose.html). The color channel needs to be first and retain the order of the other two dimensions.

# %%
def process_image(image):
    ''' Scales, crops, and normalizes a PIL image for a PyTorch model,
        returns an Numpy array
    '''

    # DONE: Process a PIL image for use in a PyTorch model
    image = Image.open(image)

    # The simplest way is use the transformation already defined
    return test_transform(image)

# %% [markdown]
# To check your work, the function below converts a PyTorch tensor and displays it in the notebook. If your `process_image` function works, running the output through this function should return the original image (except for the cropped out portions).

# %%
def imshow(image, ax=None, title=None):
    """Imshow for Tensor."""
    if ax is None:
        fig, ax = plt.subplots()

    # PyTorch tensors assume the color channel is the first dimension
    # but matplotlib assumes is the third dimension
    image = image.numpy().transpose((1, 2, 0))

    # Undo preprocessing
    mean = np.array([0.485, 0.456, 0.406])
    std = np.array([0.229, 0.224, 0.225])
    image = std * image + mean

    # Image needs to be clipped between 0 and 1 or it looks like noise when displayed
    image = np.clip(image, 0, 1)

    ax.imshow(image)

    return ax

# %%
imshow(process_image(test_dir +'/10/image_07090.jpg'))
# Out:
# <Axes: >

# %% [markdown]
# ## Class Prediction
#
# Once you can get images in the correct format, it's time to write a function for making predictions with your model. A common practice is to predict the top 5 or so (usually called top-$K$) most probable classes. You'll want to calculate the class probabilities then find the $K$ largest values.
#
# To get the top $K$ largest values in a tensor use [`x.topk(k)`](http://pytorch.org/docs/master/torch.html#torch.topk). This method returns both the highest `k` probabilities and the indices of those probabilities corresponding to the classes. You need to convert from these indices to the actual class labels using `class_to_idx` which hopefully you added to the model or from an `ImageFolder` you used to load the data ([see here](#Save-the-checkpoint)). Make sure to invert the dictionary so you get a mapping from index to class as well.
#
# Again, this method should take a path to an image and a model checkpoint, then return the probabilities and classes.
#
# ```python
# probs, classes = predict(image_path, model)
# print(probs)
# print(classes)
# > [ 0.01558163  0.01541934  0.01452626  0.01443549  0.01407339]
# > ['70', '3', '45', '62', '55']
# ```

# %%
def predict(image_path, model, topk=5):
    ''' Predict the class (or classes) of an image using a trained deep learning model.
    '''

    # Implementing the code to predict the class from an image file

    model.eval()
    with torch.no_grad():
        logps = model.forward(process_image(image_path).unsqueeze(0))
        ps = torch.exp(logps)
        probs, labels = ps.topk(topk, dim=1)

        class_to_idx_inv = {model.class_to_idx[i]: i for i in model.class_to_idx}
        classes = list()

        for label in labels.numpy()[0]:
            classes.append(class_to_idx_inv[label])

        return probs.numpy()[0], classes

# %%
probs, classes = predict(test_dir + '/12/image_04012.jpg', model)
print(probs)
print(classes)
# Out:
# [0.0805527  0.06491348 0.04767917 0.0474813  0.0428938 ]
# ['67', '14', '65', '54', '17']

# %% [markdown]
# ## Sanity Checking
#
# Now that you can use a trained model for predictions, check to make sure it makes sense. Even if the testing accuracy is high, it's always good to check that there aren't obvious bugs. Use `matplotlib` to plot the probabilities for the top 5 classes as a bar graph, along with the input image. It should look like this:
#
# <img src='assets/inference_example.png' width=300px>
#
# You can convert from the class integer encoding to actual flower names with the `cat_to_name.json` file (should have been loaded earlier in the notebook). To show a PyTorch tensor as an image, use the `imshow` function defined above.

# %%
# Displaying an image along with the top 5 classes
import seaborn as sns
image_path = test_dir + '/4/image_05640.jpg'
image_class = '4'

predict_probs, predict_classes = predict(image_path, model)

classes = []
for predict_class in predict_classes:
    classes.append(cat_to_name[predict_class])

fig = plt.figure(figsize = (12,10))

# Plotting Image
ax = plt.subplot(2,1,1)
ax.set_title(cat_to_name[image_class])
plt.axis('off')
imshow(process_image(image_path), ax, title="lol");

# Plotting probabilities
plt.subplot(2,1,2)
sns.barplot(x=predict_probs, y=classes, color='cornflowerblue');
plt.show()

# %%
# Installing the nbconvert package in Google Colab to convert the .ipynb to .html file
# !pip install nbconvert

# %%
# Converting the .ipynb to .html file
# !jupyter nbconvert --to html /content/drive/MyDrive/ColabNotebooks/Image_Classifier_Project.ipynb
# Out:
# [NbConvertApp] Converting notebook /content/drive/MyDrive/ColabNotebooks/Image_Classifier_Project.ipynb to html
# [NbConvertApp] Writing 1631796 bytes to /content/drive/MyDrive/ColabNotebooks/Image_Classifier_Project.html

# %% [markdown]
# ## Reminder for Workspace users
# If your network becomes very large when saved as a checkpoint, there might be issues with saving backups in your workspace. You should reduce the size of your hidden layers and train again.
#
# We strongly encourage you to delete these large interim files and directories before navigating to another page or closing the browser tab.

# %%
# TODO remove .pth files or move it to a temporary `~/opt` directory in this Workspace
